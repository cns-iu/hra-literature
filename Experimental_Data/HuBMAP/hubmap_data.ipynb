# %% [markdown]
# ## HuBMAP metadata analysis

# %%
import requests
import pandas as pd
import time
from tqdm import tqdm
import os
from pathlib import Path
import json

# %%
def get_hubmap_metadata(uuid: str, ):
    URL = f"https://portal.hubmapconsortium.org/browse/dataset/{uuid}"
    if "json" not in uuid:
        URL = f"https://portal.hubmapconsortium.org/browse/dataset/{uuid}.json"
    
    response = requests.get(URL)
    return response

# %%
get_hubmap_metadata(uuid="0de3181b777383b7b918d4402021fb34")
# Out:
# <Response [200]>

# %%
def json_tree(element, n=0, type_=False):
    if isinstance(element, dict):
        for k,v in element.items():
            print("     "*n, k, ": ", type(v).__name__)
            json_tree(v, n+1)
        

    elif isinstance(element, list):
        if len(element) > 0:
            temp = [ele for ele in element if isinstance(ele, dict) or isinstance(ele, list)]
            # max_ele = sorted(temp.items(), key=lambda item: len(item[1]))[-1]
            max_vals = 0
            max_item = {}
            for item in temp:
                if len(item) > max_vals:
                    max_vals = len(item)
                    max_item = item

            # if isinstance(element[0], dict) or isinstance(element[0], list):
            #     json_tree(element[0], n+1)
            # print("")

            json_tree(max_item, n+1)
            print("")

# %% [markdown]
# List of all json IDs.

# %%
def get_list_of_uuids():
    hubmap_metadata_general_url = "https://portal.hubmapconsortium.org/metadata/v0/datasets.tsv"
    df_raw = pd.read_csv(hubmap_metadata_general_url, delimiter='\t')
    hubmap_uuids = df_raw['uuid'][1:].tolist()
    return hubmap_uuids

# %%
hubmap_uuids = get_list_of_uuids()

# %%
# resp = get_hubmap_metadata(uuid=hubmap_uuids[1])
resp = get_hubmap_metadata(uuid="0de3181b777383b7b918d4402021fb34")

# %%
for key,value in resp.json().items():
    print(key, type(value))
# Out:
# ancestor_counts <class 'dict'>
# ancestor_ids <class 'list'>
# ancestors <class 'list'>
# contacts <class 'list'>
# contains_human_genetic_sequences <class 'bool'>
# contributors <class 'list'>
# created_by_user_displayname <class 'str'>
# created_by_user_email <class 'str'>
# created_timestamp <class 'int'>
# data_access_level <class 'str'>
# data_types <class 'list'>
# descendant_counts <class 'dict'>
# descendant_ids <class 'list'>
# descendants <class 'list'>
# description <class 'str'>
# display_subtype <class 'str'>
# doi_url <class 'str'>
# donor <class 'dict'>
# entity_type <class 'str'>
# files <class 'list'>
# group_name <class 'str'>
# group_uuid <class 'str'>
# hubmap_id <class 'str'>
# immediate_ancestors <class 'list'>
# immediate_descendants <class 'list'>
# index_version <class 'str'>
# last_modified_timestamp <class 'int'>
# mapped_consortium <class 'str'>
# mapped_data_access_level <class 'str'>
# mapped_data_types <class 'list'>
# mapped_last_modified_timestamp <class 'str'>
# mapped_metadata <class 'dict'>
# mapped_status <class 'str'>
# mapper_metadata <class 'dict'>
# metadata <class 'dict'>
# origin_sample <class 'dict'>
# origin_samples <class 'list'>
# origin_samples_unique_mapped_organs <class 'list'>
# provider_info <class 'str'>
# published_timestamp <class 'int'>
# registered_doi <class 'str'>
# source_sample <class 'list'>
# source_samples <class 'list'>
# status <class 'str'>
# title <class 'str'>
# uuid <class 'str'>

# %%
resp.json()
# Out:
# {'ancestor_counts': {'entity_type': {'Donor': 1, 'Sample': 3}},
#  'ancestor_ids': ['4d750b2cdad1579bb3bd5d89b9223431',
#   '84ee6955a5ddab4aee0f467609e96c2f',
#   '5d079766bf17544745c38d88d6923dbf',
#   'be425f8a2963dda1d3a7a0c79de5e466'],
#  'ancestors': [{'created_by_user_displayname': 'Daniel Cotter',
#    'created_by_user_email': 'Daniel.cotter@stanford.edu',
#    'created_timestamp': 1615604169051,
#    'data_access_level': 'public',
#    'description': 'jejunum (small intestine) sample B005-A-402',
#    'entity_type': 'Sample',
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM459.PPCQ.388',
#    'lab_tissue_sample_id': 'B005-A-402',
#    'last_modified_timestamp': 1645203410702,
#    'mapped_data_access_level': 'Public',
#    'mapped_last_modified_timestamp': '2022-02-18 16:56:50',
#    'mapped_metadata': {},
#    'mapped_sample_category': 'Block',
#    'metadata': {'cold_ischemia_time_unit': 'minutes',
#     'cold_ischemia_time_value': '196',
#     'health_status': 'relatively healthy',
#     'organ_condition': 'healthy',
#     'pathologist_report': 'normal, no cancer, no necrosis',
#     'perfusion_solution': 'HTK',
#     'procedure_date': '2020-07-27',
#     'specimen_preservation_temperature': 'Liquid Nitrogen',
#     'specimen_quality_criteria': 'H&E',
#     'specimen_tumor_distance_unit': '',
#     'specimen_tumor_distance_value': '',
#     'vital_state': 'deceased',
#     'warm_ischemia_time_unit': 'minutes',
#     'warm_ischemia_time_value': '0'},
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#    'rui_location': '{"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/74c8746d-be53-493d-9a2a-1edbe24f0d16", "@type": "SpatialEntity", "ccf_annotations": ["http://purl.obolibrary.org/obo/UBERON_0002115"], "creation_date": "2022-02-18", "creator": "Yiing Lin", "creator_first_name": "Yiing", "creator_last_name": "Lin", "dimension_units": "millimeter", "placement": {"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/74c8746d-be53-493d-9a2a-1edbe24f0d16_placement", "@type": "SpatialPlacement", "placement_date": "2022-02-18", "rotation_order": "XYZ", "rotation_units": "degree", "scaling_units": "ratio", "target": "http://purl.org/ccf/latest/ccf.owl#VHFSmallIntestine", "translation_units": "millimeter", "x_rotation": 59, "x_scaling": 1, "x_translation": 81.38, "y_rotation": 19, "y_scaling": 1, "y_translation": 156.91, "z_rotation": -56, "z_scaling": 1, "z_translation": 21.022}, "x_dimension": 3, "y_dimension": 30, "z_dimension": 15}',
#    'sample_category': 'block',
#    'specimen_type': 'flash_frozen_liquid_nitrogen',
#    'submission_id': 'STAN0008-SI-2-1',
#    'tissue_type': 'Block',
#    'uuid': '4d750b2cdad1579bb3bd5d89b9223431'},
#   {'created_by_user_displayname': 'Daniel Cotter',
#    'created_by_user_email': 'Daniel.cotter@stanford.edu',
#    'created_timestamp': 1611792385882,
#    'data_access_level': 'public',
#    'entity_type': 'Sample',
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM686.NRXW.383',
#    'last_modified_timestamp': 1645732139036,
#    'mapped_data_access_level': 'Public',
#    'mapped_last_modified_timestamp': '2022-02-24 19:48:59',
#    'mapped_sample_category': 'Block',
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#    'rui_location': '{"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/a315cf4f-12d6-4e6c-9ee9-c6a06838716a", "@type": "SpatialEntity", "ccf_annotations": ["http://purl.obolibrary.org/obo/UBERON_0002115"], "creation_date": "2022-02-24", "creator": "Yiing Lin", "creator_first_name": "Yiing", "creator_last_name": "Lin", "dimension_units": "millimeter", "placement": {"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/a315cf4f-12d6-4e6c-9ee9-c6a06838716a_placement", "@type": "SpatialPlacement", "placement_date": "2022-02-24", "rotation_order": "XYZ", "rotation_units": "degree", "scaling_units": "ratio", "target": "http://purl.org/ccf/latest/ccf.owl#VHFSmallIntestine", "translation_units": "millimeter", "x_rotation": 59, "x_scaling": 1, "x_translation": 81.38, "y_rotation": 19, "y_scaling": 1, "y_translation": 156.91, "z_rotation": -56, "z_scaling": 1, "z_translation": 21.022}, "x_dimension": 3, "y_dimension": 30, "z_dimension": 15}',
#    'sample_category': 'block',
#    'specimen_type': 'organ_piece',
#    'submission_id': 'STAN0008-SI-2',
#    'tissue_type': 'Block',
#    'uuid': '84ee6955a5ddab4aee0f467609e96c2f'},
#   {'created_by_user_displayname': 'Daniel Cotter',
#    'created_by_user_email': 'Daniel.cotter@stanford.edu',
#    'created_timestamp': 1611790091736,
#    'data_access_level': 'public',
#    'entity_type': 'Sample',
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM628.HGNP.547',
#    'last_modified_timestamp': 1611790091736,
#    'mapped_data_access_level': 'Public',
#    'mapped_last_modified_timestamp': '2021-01-27 23:28:11',
#    'mapped_organ': 'Small Intestine',
#    'mapped_sample_category': 'Organ',
#    'organ': 'SI',
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#    'sample_category': 'organ',
#    'specimen_type': 'organ',
#    'submission_id': 'STAN0008-SI',
#    'tissue_type': 'Unknown',
#    'uuid': '5d079766bf17544745c38d88d6923dbf'},
#   {'created_by_user_displayname': 'Daniel Cotter',
#    'created_by_user_email': 'Daniel.cotter@stanford.edu',
#    'created_timestamp': 1611779579789,
#    'data_access_level': 'public',
#    'entity_type': 'Donor',
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM765.TRHD.452',
#    'lab_donor_id': 'STAN0008',
#    'label': 'W128/B005',
#    'last_modified_timestamp': 1611789480636,
#    'mapped_data_access_level': 'Public',
#    'mapped_last_modified_timestamp': '2021-01-27 23:18:00',
#    'mapped_metadata': {'age_unit': ['years'],
#     'age_value': [24.0],
#     'blood_type': ['A'],
#     'body_mass_index_unit': ['kg/m^2'],
#     'body_mass_index_value': [23.2],
#     'cause_of_death': ['Cerebral edema', 'Liver failure'],
#     'death_event': ['Natural causes'],
#     'height_unit': ['cm'],
#     'height_value': [170.2],
#     'kidney_donor_profile_index_unit': ['percent'],
#     'kidney_donor_profile_index_value': [11.0],
#     'mechanism_of_injury': ['Natural causes'],
#     'race': ['White'],
#     'sex': ['Female'],
#     'social_history': ['Heavy drinker', 'Intravenous drug user'],
#     'weight_unit': ['kg'],
#     'weight_value': [67.3]},
#    'metadata': {'organ_donor_data': [{'code': '1086007',
#       'concept_id': 'C0086287',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '57312000',
#       'grouping_concept': 'C1522384',
#       'grouping_concept_preferred_term': 'Sex',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'Female',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': '413773004',
#       'concept_id': 'C0007457',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '415229000',
#       'grouping_concept': 'C0034510',
#       'grouping_concept_preferred_term': 'Race',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'White',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': '424144002',
#       'concept_id': 'C0001779',
#       'data_type': 'Numeric',
#       'data_value': '24',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '424144002',
#       'grouping_concept': 'C0001779',
#       'grouping_concept_preferred_term': 'Age',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': 'EQ',
#       'preferred_term': 'Age',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': 'years'},
#      {'code': '60621009',
#       'concept_id': 'C1305855',
#       'data_type': 'Numeric',
#       'data_value': '23.2',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '60621009',
#       'grouping_concept': 'C1305855',
#       'grouping_concept_preferred_term': 'Body mass index',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': 'EQ',
#       'preferred_term': 'Body mass index',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': 'kg/m^2'},
#      {'code': '27113001',
#       'concept_id': 'C0005910',
#       'data_type': 'Numeric',
#       'data_value': '67.3',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '27113001',
#       'grouping_concept': 'C0005910',
#       'grouping_concept_preferred_term': 'Weight',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': 'EQ',
#       'preferred_term': 'Weight',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': 'kg'},
#      {'code': '50373000',
#       'concept_id': 'C0005890',
#       'data_type': 'Numeric',
#       'data_value': '170.2',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '50373000',
#       'grouping_concept': 'C0005890',
#       'grouping_concept_preferred_term': 'Height',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': 'EQ',
#       'preferred_term': 'Height',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': 'cm'},
#      {'code': '25702006',
#       'concept_id': 'C0001969',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '160476009',
#       'grouping_concept': 'C0424945',
#       'grouping_concept_preferred_term': 'Social history',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'Heavy drinker',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': '228388006',
#       'concept_id': 'C0242566',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2020AB',
#       'grouping_code': '160476009',
#       'grouping_concept': 'C0424945',
#       'grouping_concept_preferred_term': 'Social history',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'Intravenous drug user',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': '112144000',
#       'concept_id': 'C0427620',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '44608003',
#       'grouping_concept': 'C0005844',
#       'grouping_concept_preferred_term': 'Blood type',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'A',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': 'C130310',
#       'concept_id': 'C4330523',
#       'data_type': 'Numeric',
#       'data_value': '11',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': 'C130310',
#       'grouping_concept': 'C4330523',
#       'grouping_concept_preferred_term': 'Kidney donor profile index',
#       'grouping_sab': 'NCI',
#       'numeric_operator': 'EQ',
#       'preferred_term': 'Kidney donor profile index',
#       'sab': 'NCI',
#       'start_datetime': '0',
#       'units': 'percent'},
#      {'code': '2032001',
#       'concept_id': 'C0006114',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2020AB',
#       'grouping_code': '184305005',
#       'grouping_concept': 'C0007465',
#       'grouping_concept_preferred_term': 'Cause of death',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'Cerebral edema',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': '59927004',
#       'concept_id': 'C0085605',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2020AB',
#       'grouping_code': '184305005',
#       'grouping_concept': 'C0007465',
#       'grouping_concept_preferred_term': 'Cause of death',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'Liver failure',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': '38605008',
#       'concept_id': 'C0277610',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '246078001',
#       'grouping_concept': 'C0449413',
#       'grouping_concept_preferred_term': 'Mechanism of injury',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'Natural causes',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''},
#      {'code': '38605008',
#       'concept_id': 'C0277610',
#       'data_type': 'Nominal',
#       'data_value': '',
#       'end_datetime': '',
#       'graph_version': 'UMLS2019AA',
#       'grouping_code': '419620001',
#       'grouping_concept': 'C0011065',
#       'grouping_concept_preferred_term': 'Death event',
#       'grouping_sab': 'SNOMEDCT_US',
#       'numeric_operator': '',
#       'preferred_term': 'Natural causes',
#       'sab': 'SNOMEDCT_US',
#       'start_datetime': '0',
#       'units': ''}]},
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#    'submission_id': 'STAN0008',
#    'uuid': 'be425f8a2963dda1d3a7a0c79de5e466'}],
#  'contacts': [{'affiliation': 'Stanford University',
#    'first_name': 'Stephanie',
#    'is_contact': 'TRUE',
#    'last_name': 'Nevins',
#    'middle_name_or_initial': 'A',
#    'name': 'Stephanie Nevins',
#    'orcid_id': '0000-0002-2244-6703',
#    'version': '1'},
#   {'affiliation': 'Stanford University',
#    'first_name': 'Winston',
#    'is_contact': 'TRUE',
#    'last_name': 'Becker',
#    'middle_name_or_initial': 'R',
#    'name': 'Winston Becker',
#    'orcid_id': '0000-0001-7876-5060',
#    'version': '1'},
#   {'affiliation': 'Stanford University',
#    'first_name': 'Michael',
#    'is_contact': 'TRUE',
#    'last_name': 'Snyder',
#    'middle_name_or_initial': 'P',
#    'name': 'Michael Snyder',
#    'orcid_id': '0000-0003-0784-7987',
#    'version': '1'}],
#  'contains_human_genetic_sequences': True,
#  'contributors': [{'affiliation': 'Stanford University',
#    'first_name': 'Stephanie',
#    'is_contact': 'TRUE',
#    'last_name': 'Nevins',
#    'middle_name_or_initial': 'A',
#    'name': 'Stephanie Nevins',
#    'orcid_id': '0000-0002-2244-6703',
#    'version': '1'},
#   {'affiliation': 'Stanford University',
#    'first_name': 'Winston',
#    'is_contact': 'TRUE',
#    'last_name': 'Becker',
#    'middle_name_or_initial': 'R',
#    'name': 'Winston Becker',
#    'orcid_id': '0000-0001-7876-5060',
#    'version': '1'},
#   {'affiliation': 'Stanford University',
#    'first_name': 'Michael',
#    'is_contact': 'TRUE',
#    'last_name': 'Snyder',
#    'middle_name_or_initial': 'P',
#    'name': 'Michael Snyder',
#    'orcid_id': '0000-0003-0784-7987',
#    'version': '1'}],
#  'created_by_user_displayname': 'Joel Welling',
#  'created_by_user_email': 'jw1d@andrew.cmu.edu',
#  'created_timestamp': 1646777233210,
#  'data_access_level': 'protected',
#  'data_types': ['snRNAseq-10xGenomics-v3'],
#  'descendant_counts': {'entity_type': {'Dataset': 1}},
#  'descendant_ids': ['63d2ace974a9939348c9ad87bc7af4ac',
#   '8c1ad4c380ae5477d0b7875fa47e867e'],
#  'descendants': [{'contains_human_genetic_sequences': False,
#    'created_by_user_displayname': 'HuBMAP Process',
#    'created_by_user_email': 'hubmap@hubmapconsortium.org',
#    'created_timestamp': 1671111176013,
#    'data_access_level': 'public',
#    'data_types': ['salmon_sn_rnaseq_10x'],
#    'dataset_info': 'salmon_rnaseq_10x_sn__0de3181b777383b7b918d4402021fb34__salmon-rnaseq',
#    'entity_type': 'Dataset',
#    'files': [{'description': 'Disperson plot of gene expression',
#      'edam_term': 'EDAM_1.24.format_3508',
#      'is_qa_qc': False,
#      'rel_path': 'dispersion_plot.pdf',
#      'size': 895679,
#      'type': 'pdf'},
#     {'description': 'Genome build information in JSON format',
#      'edam_term': 'EDAM_1.24.format_3464',
#      'is_qa_qc': False,
#      'rel_path': 'genome_build.json',
#      'size': 106,
#      'type': 'json'},
#     {'description': "Normalized gene expression with additional metadata, in HDF5 format, readable with the 'anndata' Python package",
#      'edam_term': 'EDAM_1.24.format_3590',
#      'is_qa_qc': False,
#      'rel_path': 'secondary_analysis.h5ad',
#      'size': 1074718106,
#      'type': 'h5ad'},
#     {'description': 'Quality control report in JSON format',
#      'edam_term': 'EDAM_1.24.format_3464',
#      'is_qa_qc': True,
#      'rel_path': 'qc_results.json',
#      'size': 451,
#      'type': 'json'},
#     {'description': 'scVelo RNA velocity grid plot',
#      'edam_term': 'EDAM_1.24.format_3508',
#      'is_qa_qc': False,
#      'rel_path': 'scvelo_embedding_grid.pdf',
#      'size': 298566,
#      'type': 'pdf'},
#     {'description': "RNA velocity results, in HDF5 format, readable with the 'anndata' Python package",
#      'edam_term': 'EDAM_1.24.format_3590',
#      'is_qa_qc': False,
#      'rel_path': 'scvelo_annotated.h5ad',
#      'size': 640118877,
#      'type': 'h5ad'},
#     {'description': 'UMAP plot of cells, colored by Leiden cluster ID',
#      'edam_term': 'EDAM_1.24.format_3508',
#      'is_qa_qc': False,
#      'rel_path': 'umap_by_leiden_cluster.pdf',
#      'size': 118748,
#      'type': 'pdf'},
#     {'description': "Raw gene expression, in HDF5 format, readable with the 'anndata' Python package, intronic counts as AnnData layer",
#      'edam_term': 'EDAM_1.24.format_3590',
#      'is_qa_qc': False,
#      'rel_path': 'expr.h5ad',
#      'size': 255812216,
#      'type': 'h5ad'},
#     {'description': 'UMAP plot of cells, colored by embedding density',
#      'edam_term': 'EDAM_1.24.format_3508',
#      'is_qa_qc': False,
#      'rel_path': 'umap_embedding_density.pdf',
#      'size': 1023512,
#      'type': 'pdf'},
#     {'description': 'Quality control results from Scanpy, per-cell and per-gene, in HDF5 format',
#      'edam_term': 'EDAM_1.24.format_3590',
#      'is_qa_qc': True,
#      'rel_path': 'qc_results.hdf5',
#      'size': 3437840,
#      'type': 'hdf5'},
#     {'description': "Raw gene expression, in HDF5 format, readable with the 'anndata' Python package, intronic counts as AnnData layer",
#      'edam_term': 'EDAM_1.24.format_3590',
#      'is_qa_qc': False,
#      'rel_path': 'raw_expr.h5ad',
#      'size': 121428128,
#      'type': 'h5ad'},
#     {'description': 'FastQC report of input FASTQ file',
#      'edam_term': 'EDAM_1.24.format_2331',
#      'is_qa_qc': True,
#      'rel_path': 'fastqc_output/B005-A-402_S6_L002_I1_001_fastqc.html',
#      'size': 417107,
#      'type': 'unknown'},
#     {'description': 'FastQC report of input FASTQ file',
#      'edam_term': 'EDAM_1.24.format_2331',
#      'is_qa_qc': True,
#      'rel_path': 'fastqc_output/B005-A-402_S6_L002_R1_001_fastqc.html',
#      'size': 512969,
#      'type': 'unknown'},
#     {'description': 'FastQC report of input FASTQ file',
#      'edam_term': 'EDAM_1.24.format_2331',
#      'is_qa_qc': True,
#      'rel_path': 'fastqc_output/B005-A-402_S6_L001_R1_001_fastqc.html',
#      'size': 509109,
#      'type': 'unknown'},
#     {'description': 'FastQC report of input FASTQ file',
#      'edam_term': 'EDAM_1.24.format_2331',
#      'is_qa_qc': True,
#      'rel_path': 'fastqc_output/B005-A-402_S6_L001_I1_001_fastqc.html',
#      'size': 421639,
#      'type': 'unknown'},
#     {'description': 'FastQC report of input FASTQ file',
#      'edam_term': 'EDAM_1.24.format_2331',
#      'is_qa_qc': True,
#      'rel_path': 'fastqc_output/B005-A-402_S6_L002_R2_001_fastqc.html',
#      'size': 641530,
#      'type': 'unknown'},
#     {'description': 'FastQC report of input FASTQ file',
#      'edam_term': 'EDAM_1.24.format_2331',
#      'is_qa_qc': True,
#      'rel_path': 'fastqc_output/B005-A-402_S6_L001_R2_001_fastqc.html',
#      'size': 638938,
#      'type': 'unknown'},
#     {'description': 'Input data relevant for visualization saved in columnar comma-separated-file format.',
#      'edam_term': 'EDAM_1.24.format_3752',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/output/secondary_analysis.csv',
#      'size': 224355,
#      'type': 'csv'},
#     {'description': 'JSON-formatted information about this scRNA-seq run including scatterplot coordinates and clustering.',
#      'edam_term': 'EDAM_1.24.format_3464',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/output/secondary_analysis.cells.json',
#      'size': 710392,
#      'type': 'json'},
#     {'description': "JSON-formatted information about this scRNA-seq's clustering.",
#      'edam_term': 'EDAM_1.24.format_3464',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/output/secondary_analysis.factors.json',
#      'size': 146160,
#      'type': 'json'},
#     {'description': "JSON-formatted information about the heirarchy scRNA-seq's cells.",
#      'edam_term': 'EDAM_1.24.format_3464',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/output/secondary_analysis.cell-sets.json',
#      'size': 152439,
#      'type': 'json'},
#     {'description': 'Input data relevant for visualization saved in columnar Apache Arrow format.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/output/secondary_analysis.arrow',
#      'size': 171378,
#      'type': 'arrow'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/spliced/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/unspliced/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/spliced_unspliced_sum/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/obsp/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/obsp/distances/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/obsp/connectivities/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/obsm/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/velocity_graph_neg/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/velocity_params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/neighbors/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/neighbors/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/umap/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/umap/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/leiden/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/leiden/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/velocity_graph/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/pca/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/pca/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/uns/recover_dynamics/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/var/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/var/__categories/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/obs/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/obs/__categories/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/varm/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/layers/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/layers/spliced/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/layers/unspliced/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/layers/unscaled/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/layers/spliced_unspliced_sum/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obsp/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obsp/distances/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obsp/connectivities/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obsm/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/umap_density_params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/annotation_metadata/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/neighbors/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/neighbors/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/umap/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/umap/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/leiden/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/leiden/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/pca/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/pca/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/rank_genes_groups/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/rank_genes_groups/params/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/hvg/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/var/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/var/__categories/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obs/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obs/__categories/.zgroup',
#      'size': 24,
#      'type': 'unknown'},
#     {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#      'edam_term': 'EDAM_1.24.format_2333',
#      'is_qa_qc': False,
#      'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/varm/.zgroup',
#      'size': 24,
#      'type': 'unknown'}],
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM349.CWPK.258',
#    'last_modified_timestamp': 1671155740910,
#    'metadata': {'dag_provenance_list': [{'hash': 'ab4eef8',
#       'origin': 'https://github.com/hubmapconsortium/ingest-pipeline.git'},
#      {'hash': 'ab4eef8',
#       'origin': 'https://github.com/hubmapconsortium/ingest-pipeline.git'},
#      {'hash': 'd71be68',
#       'name': 'pipeline.cwl',
#       'origin': 'https://github.com/hubmapconsortium/salmon-rnaseq'},
#      {'hash': '2e4017d',
#       'name': 'pipeline.cwl',
#       'origin': 'https://github.com/hubmapconsortium/azimuth-annotate'},
#      {'hash': '1994f0f',
#       'name': 'anndata-to-ui.cwl',
#       'origin': 'https://github.com/hubmapconsortium/portal-containers'}],
#     'files': [{'description': 'Disperson plot of gene expression',
#       'edam_term': 'EDAM_1.24.format_3508',
#       'is_qa_qc': False,
#       'rel_path': 'dispersion_plot.pdf',
#       'size': 895679,
#       'type': 'pdf'},
#      {'description': 'Genome build information in JSON format',
#       'edam_term': 'EDAM_1.24.format_3464',
#       'is_qa_qc': False,
#       'rel_path': 'genome_build.json',
#       'size': 106,
#       'type': 'json'},
#      {'description': "Normalized gene expression with additional metadata, in HDF5 format, readable with the 'anndata' Python package",
#       'edam_term': 'EDAM_1.24.format_3590',
#       'is_qa_qc': False,
#       'rel_path': 'secondary_analysis.h5ad',
#       'size': 1074718106,
#       'type': 'h5ad'},
#      {'description': 'Quality control report in JSON format',
#       'edam_term': 'EDAM_1.24.format_3464',
#       'is_qa_qc': True,
#       'rel_path': 'qc_results.json',
#       'size': 451,
#       'type': 'json'},
#      {'description': 'scVelo RNA velocity grid plot',
#       'edam_term': 'EDAM_1.24.format_3508',
#       'is_qa_qc': False,
#       'rel_path': 'scvelo_embedding_grid.pdf',
#       'size': 298566,
#       'type': 'pdf'},
#      {'description': "RNA velocity results, in HDF5 format, readable with the 'anndata' Python package",
#       'edam_term': 'EDAM_1.24.format_3590',
#       'is_qa_qc': False,
#       'rel_path': 'scvelo_annotated.h5ad',
#       'size': 640118877,
#       'type': 'h5ad'},
#      {'description': 'UMAP plot of cells, colored by Leiden cluster ID',
#       'edam_term': 'EDAM_1.24.format_3508',
#       'is_qa_qc': False,
#       'rel_path': 'umap_by_leiden_cluster.pdf',
#       'size': 118748,
#       'type': 'pdf'},
#      {'description': "Raw gene expression, in HDF5 format, readable with the 'anndata' Python package, intronic counts as AnnData layer",
#       'edam_term': 'EDAM_1.24.format_3590',
#       'is_qa_qc': False,
#       'rel_path': 'expr.h5ad',
#       'size': 255812216,
#       'type': 'h5ad'},
#      {'description': 'UMAP plot of cells, colored by embedding density',
#       'edam_term': 'EDAM_1.24.format_3508',
#       'is_qa_qc': False,
#       'rel_path': 'umap_embedding_density.pdf',
#       'size': 1023512,
#       'type': 'pdf'},
#      {'description': 'Quality control results from Scanpy, per-cell and per-gene, in HDF5 format',
#       'edam_term': 'EDAM_1.24.format_3590',
#       'is_qa_qc': True,
#       'rel_path': 'qc_results.hdf5',
#       'size': 3437840,
#       'type': 'hdf5'},
#      {'description': "Raw gene expression, in HDF5 format, readable with the 'anndata' Python package, intronic counts as AnnData layer",
#       'edam_term': 'EDAM_1.24.format_3590',
#       'is_qa_qc': False,
#       'rel_path': 'raw_expr.h5ad',
#       'size': 121428128,
#       'type': 'h5ad'},
#      {'description': 'FastQC report of input FASTQ file',
#       'edam_term': 'EDAM_1.24.format_2331',
#       'is_qa_qc': True,
#       'rel_path': 'fastqc_output/B005-A-402_S6_L002_I1_001_fastqc.html',
#       'size': 417107,
#       'type': 'unknown'},
#      {'description': 'FastQC report of input FASTQ file',
#       'edam_term': 'EDAM_1.24.format_2331',
#       'is_qa_qc': True,
#       'rel_path': 'fastqc_output/B005-A-402_S6_L002_R1_001_fastqc.html',
#       'size': 512969,
#       'type': 'unknown'},
#      {'description': 'FastQC report of input FASTQ file',
#       'edam_term': 'EDAM_1.24.format_2331',
#       'is_qa_qc': True,
#       'rel_path': 'fastqc_output/B005-A-402_S6_L001_R1_001_fastqc.html',
#       'size': 509109,
#       'type': 'unknown'},
#      {'description': 'FastQC report of input FASTQ file',
#       'edam_term': 'EDAM_1.24.format_2331',
#       'is_qa_qc': True,
#       'rel_path': 'fastqc_output/B005-A-402_S6_L001_I1_001_fastqc.html',
#       'size': 421639,
#       'type': 'unknown'},
#      {'description': 'FastQC report of input FASTQ file',
#       'edam_term': 'EDAM_1.24.format_2331',
#       'is_qa_qc': True,
#       'rel_path': 'fastqc_output/B005-A-402_S6_L002_R2_001_fastqc.html',
#       'size': 641530,
#       'type': 'unknown'},
#      {'description': 'FastQC report of input FASTQ file',
#       'edam_term': 'EDAM_1.24.format_2331',
#       'is_qa_qc': True,
#       'rel_path': 'fastqc_output/B005-A-402_S6_L001_R2_001_fastqc.html',
#       'size': 638938,
#       'type': 'unknown'},
#      {'description': 'Input data relevant for visualization saved in columnar comma-separated-file format.',
#       'edam_term': 'EDAM_1.24.format_3752',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/output/secondary_analysis.csv',
#       'size': 224355,
#       'type': 'csv'},
#      {'description': 'JSON-formatted information about this scRNA-seq run including scatterplot coordinates and clustering.',
#       'edam_term': 'EDAM_1.24.format_3464',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/output/secondary_analysis.cells.json',
#       'size': 710392,
#       'type': 'json'},
#      {'description': "JSON-formatted information about this scRNA-seq's clustering.",
#       'edam_term': 'EDAM_1.24.format_3464',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/output/secondary_analysis.factors.json',
#       'size': 146160,
#       'type': 'json'},
#      {'description': "JSON-formatted information about the heirarchy scRNA-seq's cells.",
#       'edam_term': 'EDAM_1.24.format_3464',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/output/secondary_analysis.cell-sets.json',
#       'size': 152439,
#       'type': 'json'},
#      {'description': 'Input data relevant for visualization saved in columnar Apache Arrow format.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/output/secondary_analysis.arrow',
#       'size': 171378,
#       'type': 'arrow'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/spliced/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/unspliced/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/layers/spliced_unspliced_sum/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/scvelo_annotated.zarr/obsp/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of velocity analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
# ...
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/umap_density_params/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/annotation_metadata/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/neighbors/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/neighbors/params/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/umap/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/umap/params/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/leiden/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/leiden/params/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/pca/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/pca/params/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/rank_genes_groups/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/rank_genes_groups/params/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/uns/hvg/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/var/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/var/__categories/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obs/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/obs/__categories/.zgroup',
#       'size': 24,
#       'type': 'unknown'},
#      {'description': 'AnnData Zarr store for storing and visualizing single cell sequencing outputs of UMAP/clustering analysis.',
#       'edam_term': 'EDAM_1.24.format_2333',
#       'is_qa_qc': False,
#       'rel_path': 'hubmap_ui/anndata-zarr/secondary_analysis.zarr/varm/.zgroup',
#       'size': 24,
#       'type': 'unknown'}]},
#    'published_timestamp': 1671155740910,
#    'status': 'Published',
#    'title': 'snrna-seq [salmon] data from the small intestine of a 24-year-old white female',
#    'uuid': '8c1ad4c380ae5477d0b7875fa47e867e'}],
#  'index_version': '3.1.1',
#  'last_modified_timestamp': 1671155740528,
#  'mapped_consortium': 'HuBMAP',
#  'mapped_data_access_level': 'Protected',
#  'mapped_data_types': ['snRNA-seq (10x Genomics v3)'],
#  'mapped_last_modified_timestamp': '2022-12-16 01:55:40',
#  'mapped_metadata': {},
#  'mapped_status': 'Published',
#  'mapper_metadata': {'datetime': '2023-04-11 17:36:13.996708',
#   'size': 120325,
#   'validation_errors': [],
#   'version': 'main:418bbbf'},
#  'metadata': {'dag_provenance_list': [{'hash': '8f5cbe0',
#     'origin': 'https://github.com/hubmapconsortium/ingest-pipeline.git'}],
#   'extra_metadata': {'collectiontype': 'generic_metadatatsv'},
#   'files': [],
#   'metadata': {'acquisition_instrument_model': 'NovaSeq6000',
#    'acquisition_instrument_vendor': 'Illumina',
#    'analyte_class': 'RNA',
#    'assay_category': 'sequence',
#    'assay_type': 'snRNAseq-10xGenomics-v3',
#    'cell_barcode_read': 'R1',
#    'cell_barcode_size': '16',
#    'contributors_path': 'extras/snrnaseq-contributors.tsv',
#    'description': 'snrnaseq',
#    'execution_datetime': '2020-09-17 09:09',
#    'expected_cell_count': 5000,
#    'is_targeted': 'FALSE',
#    'is_technical_replicate': 'FALSE',
#    'library_adapter_sequence': 'AGATCGGAAGAGCACACGT',
#    'library_average_fragment_size': 504,
#    'library_construction_protocols_io_doi': '10.17504/protocols.io.bfwajpae',
#    'library_final_yield_unit': 'ng',
#    'library_final_yield_value': 636.0,
#    'library_id': 'B005-A-402',
#    'library_layout': 'paired-end',
#    'library_pcr_cycles': 12,
#    'library_pcr_cycles_for_sample_index': 13,
#    'operator': 'Stephanie Nevins, Roxanne Chiu',
#    'operator_email': 'snevins@stanford.edu',
#    'pi': 'Michael Snyder',
#    'pi_email': 'mpsnyder@stanford.edu',
#    'protocols_io_doi': '10.17504/protocols.io.bfwajpae',
#    'rnaseq_assay_input': 14850,
#    'rnaseq_assay_method': "10x Chromium Single Cell 3' Reagent Kits v3.1",
#    'sc_isolation_cell_number': 2300000,
#    'sc_isolation_enrichment': 'none',
#    'sc_isolation_entity': 'nucleus',
#    'sc_isolation_protocols_io_doi': '10.17504/protocols.io.bfwajpae',
#    'sc_isolation_quality_metric': 'OK',
#    'sc_isolation_tissue_dissociation': 'dounce',
#    'sequencing_phix_percent': 20,
#    'sequencing_read_format': '28/8/0/91',
#    'sequencing_read_percent_q30': 93.3,
#    'sequencing_reagent_kit': 'NovaSeq 6000 S1'}},
#  'origin_sample': {'created_by_user_displayname': 'Daniel Cotter',
#   'created_by_user_email': 'Daniel.cotter@stanford.edu',
#   'created_timestamp': 1611790091736,
#   'data_access_level': 'public',
#   'entity_type': 'Sample',
#   'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'hubmap_id': 'HBM628.HGNP.547',
#   'last_modified_timestamp': 1611790091736,
#   'mapped_data_access_level': 'Public',
#   'mapped_last_modified_timestamp': '2021-01-27 23:28:11',
#   'mapped_organ': 'Small Intestine',
#   'mapped_sample_category': 'Organ',
#   'organ': 'SI',
#   'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#   'sample_category': 'organ',
#   'specimen_type': 'organ',
#   'submission_id': 'STAN0008-SI',
#   'tissue_type': 'Unknown',
#   'uuid': '5d079766bf17544745c38d88d6923dbf'},
#  'origin_samples': [{'created_by_user_displayname': 'daniel cotter',
#    'created_by_user_email': 'Daniel.cotter@stanford.edu',
#    'created_timestamp': 1611790091736,
#    'data_access_level': 'public',
#    'entity_type': 'Sample',
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM628.HGNP.547',
#    'last_modified_timestamp': 1611790091736,
#    'mapped_data_access_level': 'Public',
#    'mapped_last_modified_timestamp': '2021-01-27 23:28:11',
#    'mapped_organ': 'Small Intestine',
#    'mapped_sample_category': 'Organ',
#    'organ': 'SI',
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#    'sample_category': 'organ',
#    'specimen_type': 'organ',
#    'submission_id': 'STAN0008-SI',
#    'tissue_type': 'Unknown',
#    'uuid': '5d079766bf17544745c38d88d6923dbf'}],
#  'origin_samples_unique_mapped_organs': ['Small Intestine'],
#  'provider_info': 'Batch 4 - snRNAseq - Dec 21 : B005-A-402',
#  'published_timestamp': 1671155740528,
#  'registered_doi': '10.35079/HBM292.FTLJ.343',
#  'source_sample': [{'created_by_user_displayname': 'daniel Cotter',
#    'created_by_user_email': 'Daniel.cotter@stanford.edu',
#    'created_timestamp': 1615604169051,
#    'data_access_level': 'public',
#    'description': 'jejunum (small intestine) sample B005-A-402',
#    'entity_type': 'Sample',
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM459.PPCQ.388',
#    'lab_tissue_sample_id': 'B005-A-402',
#    'last_modified_timestamp': 1645203410702,
#    'mapped_data_access_level': 'Public',
#    'mapped_last_modified_timestamp': '2022-02-18 16:56:50',
#    'mapped_metadata': {},
#    'mapped_sample_category': 'Block',
#    'metadata': {'cold_ischemia_time_unit': 'minutes',
#     'cold_ischemia_time_value': '196',
#     'health_status': 'relatively healthy',
#     'organ_condition': 'healthy',
#     'pathologist_report': 'normal, no cancer, no necrosis',
#     'perfusion_solution': 'HTK',
#     'procedure_date': '2020-07-27',
#     'specimen_preservation_temperature': 'Liquid Nitrogen',
#     'specimen_quality_criteria': 'H&E',
#     'specimen_tumor_distance_unit': '',
#     'specimen_tumor_distance_value': '',
#     'vital_state': 'deceased',
#     'warm_ischemia_time_unit': 'minutes',
#     'warm_ischemia_time_value': '0'},
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#    'rui_location': '{"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/74c8746d-be53-493d-9a2a-1edbe24f0d16", "@type": "SpatialEntity", "ccf_annotations": ["http://purl.obolibrary.org/obo/UBERON_0002115"], "creation_date": "2022-02-18", "creator": "Yiing Lin", "creator_first_name": "Yiing", "creator_last_name": "Lin", "dimension_units": "millimeter", "placement": {"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/74c8746d-be53-493d-9a2a-1edbe24f0d16_placement", "@type": "SpatialPlacement", "placement_date": "2022-02-18", "rotation_order": "XYZ", "rotation_units": "degree", "scaling_units": "ratio", "target": "http://purl.org/ccf/latest/ccf.owl#VHFSmallIntestine", "translation_units": "millimeter", "x_rotation": 59, "x_scaling": 1, "x_translation": 81.38, "y_rotation": 19, "y_scaling": 1, "y_translation": 156.91, "z_rotation": -56, "z_scaling": 1, "z_translation": 21.022}, "x_dimension": 3, "y_dimension": 30, "z_dimension": 15}',
#    'sample_category': 'block',
#    'specimen_type': 'flash_frozen_liquid_nitrogen',
#    'submission_id': 'STAN0008-SI-2-1',
#    'tissue_type': 'Block',
#    'uuid': '4d750b2cdad1579bb3bd5d89b9223431'}],
#  'source_samples': [{'created_by_user_displayname': 'daniel Cotter',
#    'created_by_user_email': 'Daniel.cotter@stanford.edu',
#    'created_timestamp': 1615604169051,
#    'data_access_level': 'public',
#    'description': 'jejunum (small intestine) sample B005-A-402',
#    'entity_type': 'Sample',
#    'group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#    'hubmap_id': 'HBM459.PPCQ.388',
#    'lab_tissue_sample_id': 'B005-A-402',
#    'last_modified_timestamp': 1645203410702,
#    'mapped_data_access_level': 'Public',
#    'mapped_last_modified_timestamp': '2022-02-18 16:56:50',
#    'mapped_metadata': {},
#    'mapped_sample_category': 'Block',
#    'metadata': {'cold_ischemia_time_unit': 'minutes',
#     'cold_ischemia_time_value': '196',
#     'health_status': 'relatively healthy',
#     'organ_condition': 'healthy',
#     'pathologist_report': 'normal, no cancer, no necrosis',
#     'perfusion_solution': 'HTK',
#     'procedure_date': '2020-07-27',
#     'specimen_preservation_temperature': 'Liquid Nitrogen',
#     'specimen_quality_criteria': 'H&E',
#     'specimen_tumor_distance_unit': '',
#     'specimen_tumor_distance_value': '',
#     'vital_state': 'deceased',
#     'warm_ischemia_time_unit': 'minutes',
#     'warm_ischemia_time_value': '0'},
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bin8kdhw',
#    'rui_location': '{"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/74c8746d-be53-493d-9a2a-1edbe24f0d16", "@type": "SpatialEntity", "ccf_annotations": ["http://purl.obolibrary.org/obo/UBERON_0002115"], "creation_date": "2022-02-18", "creator": "Yiing Lin", "creator_first_name": "Yiing", "creator_last_name": "Lin", "dimension_units": "millimeter", "placement": {"@context": "https://hubmapconsortium.github.io/hubmap-ontology/ccf-context.jsonld", "@id": "http://purl.org/ccf/1.5/74c8746d-be53-493d-9a2a-1edbe24f0d16_placement", "@type": "SpatialPlacement", "placement_date": "2022-02-18", "rotation_order": "XYZ", "rotation_units": "degree", "scaling_units": "ratio", "target": "http://purl.org/ccf/latest/ccf.owl#VHFSmallIntestine", "translation_units": "millimeter", "x_rotation": 59, "x_scaling": 1, "x_translation": 81.38, "y_rotation": 19, "y_scaling": 1, "y_translation": 156.91, "z_rotation": -56, "z_scaling": 1, "z_translation": 21.022}, "x_dimension": 3, "y_dimension": 30, "z_dimension": 15}',
#    'sample_category': 'block',
#    'specimen_type': 'flash_frozen_liquid_nitrogen',
#    'submission_id': 'STAN0008-SI-2-1',
#    'tissue_type': 'Block',
#    'uuid': '4d750b2cdad1579bb3bd5d89b9223431'}],
#  'status': 'Published',
#  'title': 'snrna-seq (10x genomics v3) data from the small intestine of a 24-year-old white female',
#  'uuid': '0de3181b777383b7b918d4402021fb34'}

# %%
json_tree(resp.json())
# Out:
#  ancestor_counts :  dict
#       entity_type :  dict
#            Donor :  int
#            Sample :  int
#  ancestor_ids :  list
#
#  ancestors :  list
#            created_by_user_displayname :  str
#            created_by_user_email :  str
#            created_timestamp :  int
#            data_access_level :  str
#            description :  str
#            entity_type :  str
#            group_uuid :  str
#            hubmap_id :  str
#            lab_tissue_sample_id :  str
#            last_modified_timestamp :  int
#            mapped_data_access_level :  str
#            mapped_last_modified_timestamp :  str
#            mapped_metadata :  dict
#            mapped_sample_category :  str
#            metadata :  dict
#                 cold_ischemia_time_unit :  str
#                 cold_ischemia_time_value :  str
#                 health_status :  str
#                 organ_condition :  str
#                 pathologist_report :  str
#                 perfusion_solution :  str
#                 procedure_date :  str
#                 specimen_preservation_temperature :  str
#                 specimen_quality_criteria :  str
#                 specimen_tumor_distance_unit :  str
#                 specimen_tumor_distance_value :  str
#                 vital_state :  str
#                 warm_ischemia_time_unit :  str
#                 warm_ischemia_time_value :  str
#            protocol_url :  str
#            rui_location :  str
#            sample_category :  str
#            specimen_type :  str
#            submission_id :  str
#            tissue_type :  str
#            uuid :  str
#
#  contacts :  list
#            affiliation :  str
#            first_name :  str
#            is_contact :  str
#            last_name :  str
#            middle_name_or_initial :  str
#            name :  str
#            orcid_id :  str
#            version :  str
#
#  contains_human_genetic_sequences :  bool
#  contributors :  list
#            affiliation :  str
#            first_name :  str
#            is_contact :  str
#            last_name :  str
#            middle_name_or_initial :  str
#            name :  str
#            orcid_id :  str
#            version :  str
#
#  created_by_user_displayname :  str
#  created_by_user_email :  str
#  created_timestamp :  int
#  data_access_level :  str
#  data_types :  list
#
#  descendant_counts :  dict
#       entity_type :  dict
#            Dataset :  int
#  descendant_ids :  list
#
#  descendants :  list
#            contains_human_genetic_sequences :  bool
#            created_by_user_displayname :  str
#            created_by_user_email :  str
#            created_timestamp :  int
#            data_access_level :  str
#            data_types :  list
#
#            dataset_info :  str
#            entity_type :  str
#            files :  list
#                      description :  str
#                      edam_term :  str
#                      is_qa_qc :  bool
#                      rel_path :  str
#                      size :  int
#                      type :  str
#
#            group_uuid :  str
#            hubmap_id :  str
#            last_modified_timestamp :  int
#            metadata :  dict
#                 dag_provenance_list :  list
#                           hash :  str
#                           name :  str
#                           origin :  str
#
#                 files :  list
#                           description :  str
#                           edam_term :  str
#                           is_qa_qc :  bool
#                           rel_path :  str
#                           size :  int
#                           type :  str
#
#            published_timestamp :  int
#            status :  str
#            title :  str
#            uuid :  str
#
#  description :  str
#  display_subtype :  str
#  doi_url :  str
#  donor :  dict
#       created_by_user_displayname :  str
#       created_by_user_email :  str
#       created_timestamp :  int
#       data_access_level :  str
#       entity_type :  str
#       group_uuid :  str
#       hubmap_id :  str
#       lab_donor_id :  str
#       label :  str
#       last_modified_timestamp :  int
#       mapped_data_access_level :  str
#       mapped_last_modified_timestamp :  str
#       mapped_metadata :  dict
#            age_unit :  list
#
#            age_value :  list
#
#            blood_type :  list
#
#            body_mass_index_unit :  list
#
#            body_mass_index_value :  list
#
#            cause_of_death :  list
#
#            death_event :  list
#
#            height_unit :  list
#
#            height_value :  list
#
#            kidney_donor_profile_index_unit :  list
#
#            kidney_donor_profile_index_value :  list
#
#            mechanism_of_injury :  list
#
#            race :  list
#
#            sex :  list
#
#            social_history :  list
#
#            weight_unit :  list
#
#            weight_value :  list
#
#       metadata :  dict
#            organ_donor_data :  list
#                      code :  str
#                      concept_id :  str
#                      data_type :  str
#                      data_value :  str
#                      end_datetime :  str
#                      graph_version :  str
#                      grouping_code :  str
#                      grouping_concept :  str
#                      grouping_concept_preferred_term :  str
#                      grouping_sab :  str
#                      numeric_operator :  str
#                      preferred_term :  str
#                      sab :  str
#                      start_datetime :  str
#                      units :  str
#
#       protocol_url :  str
#       submission_id :  str
#       uuid :  str
#  entity_type :  str
#  files :  list
#  group_name :  str
#  group_uuid :  str
#  hubmap_id :  str
#  immediate_ancestors :  list
#            created_by_user_displayname :  str
#            created_by_user_email :  str
#            created_timestamp :  int
#            data_access_level :  str
#            description :  str
#            entity_type :  str
#            group_uuid :  str
#            hubmap_id :  str
#            lab_tissue_sample_id :  str
#            last_modified_timestamp :  int
#            metadata :  dict
#                 cold_ischemia_time_unit :  str
#                 cold_ischemia_time_value :  str
#                 health_status :  str
#                 organ_condition :  str
#                 pathologist_report :  str
#                 perfusion_solution :  str
#                 procedure_date :  str
#                 specimen_preservation_temperature :  str
#                 specimen_quality_criteria :  str
#                 specimen_tumor_distance_unit :  str
#                 specimen_tumor_distance_value :  str
#                 vital_state :  str
#                 warm_ischemia_time_unit :  str
#                 warm_ischemia_time_value :  str
#            protocol_url :  str
#            rui_location :  str
#            sample_category :  str
#            specimen_type :  str
#            submission_id :  str
#            tissue_type :  str
#            uuid :  str
#
#  immediate_descendants :  list
#            contains_human_genetic_sequences :  bool
#            created_by_user_displayname :  str
#            created_by_user_email :  str
#            created_timestamp :  int
#            data_access_level :  str
#            data_types :  list
#
#            dataset_info :  str
#            entity_type :  str
#            files :  list
#                      description :  str
#                      edam_term :  str
#                      is_qa_qc :  bool
#                      rel_path :  str
#                      size :  int
#                      type :  str
#
#            group_uuid :  str
#            hubmap_id :  str
#            last_modified_timestamp :  int
#            metadata :  dict
#                 dag_provenance_list :  list
#                           hash :  str
#                           name :  str
#                           origin :  str
#
#                 files :  list
#                           description :  str
#                           edam_term :  str
#                           is_qa_qc :  bool
#                           rel_path :  str
#                           size :  int
#                           type :  str
#
#            published_timestamp :  int
#            status :  str
#            title :  str
#            uuid :  str
#
#  index_version :  str
#  last_modified_timestamp :  int
#  mapped_consortium :  str
#  mapped_data_access_level :  str
#  mapped_data_types :  list
#
#  mapped_last_modified_timestamp :  str
#  mapped_metadata :  dict
#  mapped_status :  str
#  mapper_metadata :  dict
#       datetime :  str
#       size :  int
#       validation_errors :  list
#       version :  str
#  metadata :  dict
#       dag_provenance_list :  list
#                 hash :  str
#                 origin :  str
#
#       extra_metadata :  dict
#            collectiontype :  str
#       files :  list
#       metadata :  dict
#            acquisition_instrument_model :  str
#            acquisition_instrument_vendor :  str
#            analyte_class :  str
#            assay_category :  str
#            assay_type :  str
#            cell_barcode_read :  str
#            cell_barcode_size :  str
#            contributors_path :  str
#            description :  str
#            execution_datetime :  str
#            expected_cell_count :  int
#            is_targeted :  str
#            is_technical_replicate :  str
#            library_adapter_sequence :  str
#            library_average_fragment_size :  int
#            library_construction_protocols_io_doi :  str
#            library_final_yield_unit :  str
#            library_final_yield_value :  float
#            library_id :  str
#            library_layout :  str
#            library_pcr_cycles :  int
#            library_pcr_cycles_for_sample_index :  int
#            operator :  str
#            operator_email :  str
#            pi :  str
#            pi_email :  str
#            protocols_io_doi :  str
#            rnaseq_assay_input :  int
#            rnaseq_assay_method :  str
#            sc_isolation_cell_number :  int
#            sc_isolation_enrichment :  str
#            sc_isolation_entity :  str
#            sc_isolation_protocols_io_doi :  str
#            sc_isolation_quality_metric :  str
#            sc_isolation_tissue_dissociation :  str
#            sequencing_phix_percent :  int
#            sequencing_read_format :  str
#            sequencing_read_percent_q30 :  float
#            sequencing_reagent_kit :  str
#  origin_sample :  dict
#       created_by_user_displayname :  str
#       created_by_user_email :  str
#       created_timestamp :  int
#       data_access_level :  str
#       entity_type :  str
#       group_uuid :  str
#       hubmap_id :  str
#       last_modified_timestamp :  int
#       mapped_data_access_level :  str
#       mapped_last_modified_timestamp :  str
#       mapped_organ :  str
#       mapped_sample_category :  str
#       organ :  str
#       protocol_url :  str
#       sample_category :  str
#       specimen_type :  str
#       submission_id :  str
#       tissue_type :  str
#       uuid :  str
#  origin_samples :  list
#            created_by_user_displayname :  str
#            created_by_user_email :  str
#            created_timestamp :  int
#            data_access_level :  str
#            entity_type :  str
#            group_uuid :  str
#            hubmap_id :  str
#            last_modified_timestamp :  int
#            mapped_data_access_level :  str
#            mapped_last_modified_timestamp :  str
#            mapped_organ :  str
#            mapped_sample_category :  str
#            organ :  str
#            protocol_url :  str
#            sample_category :  str
#            specimen_type :  str
#            submission_id :  str
#            tissue_type :  str
#            uuid :  str
#
#  origin_samples_unique_mapped_organs :  list
#
#  provider_info :  str
#  published_timestamp :  int
#  registered_doi :  str
#  source_sample :  list
#            created_by_user_displayname :  str
#            created_by_user_email :  str
#            created_timestamp :  int
#            data_access_level :  str
#            description :  str
#            entity_type :  str
#            group_uuid :  str
#            hubmap_id :  str
#            lab_tissue_sample_id :  str
#            last_modified_timestamp :  int
#            mapped_data_access_level :  str
#            mapped_last_modified_timestamp :  str
#            mapped_metadata :  dict
#            mapped_sample_category :  str
#            metadata :  dict
#                 cold_ischemia_time_unit :  str
#                 cold_ischemia_time_value :  str
#                 health_status :  str
#                 organ_condition :  str
#                 pathologist_report :  str
#                 perfusion_solution :  str
#                 procedure_date :  str
#                 specimen_preservation_temperature :  str
#                 specimen_quality_criteria :  str
#                 specimen_tumor_distance_unit :  str
#                 specimen_tumor_distance_value :  str
#                 vital_state :  str
#                 warm_ischemia_time_unit :  str
#                 warm_ischemia_time_value :  str
#            protocol_url :  str
#            rui_location :  str
#            sample_category :  str
#            specimen_type :  str
#            submission_id :  str
#            tissue_type :  str
#            uuid :  str
#
#  source_samples :  list
#            created_by_user_displayname :  str
#            created_by_user_email :  str
#            created_timestamp :  int
#            data_access_level :  str
#            description :  str
#            entity_type :  str
#            group_uuid :  str
#            hubmap_id :  str
#            lab_tissue_sample_id :  str
#            last_modified_timestamp :  int
#            mapped_data_access_level :  str
#            mapped_last_modified_timestamp :  str
#            mapped_metadata :  dict
#            mapped_sample_category :  str
#            metadata :  dict
#                 cold_ischemia_time_unit :  str
#                 cold_ischemia_time_value :  str
#                 health_status :  str
#                 organ_condition :  str
#                 pathologist_report :  str
#                 perfusion_solution :  str
#                 procedure_date :  str
#                 specimen_preservation_temperature :  str
#                 specimen_quality_criteria :  str
#                 specimen_tumor_distance_unit :  str
#                 specimen_tumor_distance_value :  str
#                 vital_state :  str
#                 warm_ischemia_time_unit :  str
#                 warm_ischemia_time_value :  str
#            protocol_url :  str
#            rui_location :  str
#            sample_category :  str
#            specimen_type :  str
#            submission_id :  str
#            tissue_type :  str
#            uuid :  str
#
#  status :  str
#  title :  str
#  uuid :  str

# %%
def get_list_of_uuids():
    hubmap_metadata_general_url = "https://portal.hubmapconsortium.org/metadata/v0/datasets.tsv"
    df_raw = pd.read_csv(hubmap_metadata_general_url, delimiter='\t')
    hubmap_uuids = df_raw['uuid'][1:].tolist()
    return hubmap_uuids


def get_hubmap_metadata(uuid: str, ):
    URL = f"https://portal.hubmapconsortium.org/browse/dataset/{uuid}"
    if "json" not in uuid:
        URL = f"https://portal.hubmapconsortium.org/browse/dataset/{uuid}.json"
    
    response = requests.get(URL)
    return response


def get_all_hubmap_dataset_metadata_Sequential():
    all_dataset_metadata = {}
    failed_fetches = []
    hubmap_uuids = get_list_of_uuids()
    for i, uuid in tqdm(enumerate(hubmap_uuids), desc="Fetching HuBMAP dataset metadata: "):
        response = get_hubmap_metadata(uuid=uuid)
        if response.status_code != 200:
            failed_fetches.append(uuid)
        else:
            all_dataset_metadata[uuid] = response.json()

        if i % 100 == 0:
            time.sleep(5)  

    return all_dataset_metadata, failed_fetches

# %%
all_dataset_metadata, failed_fetches = get_all_hubmap_dataset_metadata_Sequential()
# Out:
# Fetching HuBMAP dataset metadata: : 1330it [14:10,  1.56it/s]

# %%
with open("sample.json", "w") as outfile:
    json.dump(all_dataset_metadata, outfile)

# %%
failed_fetches
# Out:
# []

# %%
len(all_dataset_metadata.keys())
# Out:
# 1330

# %% [markdown]
# # HuBMAP data dump exploration

# %%
all_dataset_metadata = None
with open("sample.json", "r") as f:
    all_dataset_metadata = json.load(f)

# %%
fields = {k:list(v.keys()) for k,v in all_dataset_metadata.items()}

# %%
fields_counter = {}
for k,v in fields.items():
    for feature in v:
        if feature not in fields_counter:
            fields_counter[feature] = 0
        fields_counter[feature] += 1

# %%
fields_counter
# Out:
# {'anatomy_0': 1131,
#  'anatomy_1': 1131,
#  'ancestor_counts': 1321,
#  'ancestor_ids': 1321,
#  'ancestors': 1321,
#  'contacts': 848,
#  'contains_human_genetic_sequences': 1321,
#  'contributors': 919,
#  'created_by_user_displayname': 1321,
#  'created_by_user_email': 1321,
#  'created_timestamp': 1321,
#  'data_access_level': 1321,
#  'data_types': 1321,
#  'dataset_info': 1182,
#  'descendant_counts': 1321,
#  'descendant_ids': 1321,
#  'descendants': 1321,
#  'description': 900,
#  'display_subtype': 1321,
#  'doi_url': 848,
#  'donor': 1321,
#  'entity_type': 1321,
#  'files': 1321,
#  'group_name': 1321,
#  'group_uuid': 1321,
#  'hubmap_id': 1321,
#  'immediate_ancestors': 1321,
#  'immediate_descendants': 1321,
#  'index_version': 1321,
#  'lab_dataset_id': 857,
#  'last_modified_timestamp': 1321,
#  'mapped_consortium': 1321,
#  'mapped_data_access_level': 1321,
#  'mapped_data_types': 1321,
#  'mapped_last_modified_timestamp': 1321,
#  'mapped_metadata': 1302,
#  'mapped_status': 1321,
#  'mapper_metadata': 1321,
#  'metadata': 1302,
#  'origin_sample': 1321,
#  'origin_samples': 1321,
#  'published_timestamp': 1321,
#  'registered_doi': 848,
#  'source_sample': 1321,
#  'source_samples': 1321,
#  'status': 1321,
#  'title': 1321,
#  'uuid': 1321,
#  'next_revision_uuid': 62,
#  'anatomy_2': 672,
#  'previous_revision_uuid': 62,
#  'provider_info': 122,
#  'thumbnail_file': 36,
#  'mapped_external_group_name': 8}

# %%
all_dataset_metadata

# %% [markdown]
# ## HuBMAP restricted Data:
# - Search API

# %%
BASE_URL = "https://search.api.hubmapconsortium.org/v3/" 
endpoint = "indices"
URL = BASE_URL + endpoint
resp = requests.get(URL)

# %%
resp.json()
# Out:
# {'indices': ['entities', 'portal', 'hm_antibodies', 'files']}

# %%
headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json',
}

DSL_Query = {
  "query": {
    "bool": {
      "must": [
        {
          "match_phrase": {
            "donor.publication_status": "Published"
          }
        }
      ],
      "filter": [
        {
          "match": {
            "origin_sample.entity_type": "Sample"
          }
        }
      ]
    }
  }
}

BASE_URL = "https://search.api.hubmapconsortium.org/v3/" 
endpoint = "search"
URL = BASE_URL + endpoint
resp = requests.post(URL, headers=headers, json=DSL_Query)

# %%
resp.json()
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [],
#   'max_score': None,
#   'total': {'relation': 'eq', 'value': 0}},
#  'timed_out': False,
#  'took': 1}

# %%
resp
# Out:
# b'{"_shards":{"failed":0,"skipped":0,"successful":5,"total":5},"hits":{"hits":[],"max_score":null,"total":{"relation":"eq","value":0}},"timed_out":false,"took":1}\n'

# %%
nexus_token = "Ag8ekXMxQp5N96BynDp6y0dGgd4GVyz19wgOpqor5oKWvGkr6bS8ClVW5YEwEq6ppv1QGdD5kEONobhy5Y0w8TEkg2"
headers = {
    # 'accept': 'application/json',
    # 'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + nexus_token
}

DSL_Query = {
  "query": {
    "bool": {
      "should": [
        {
          "match_phrase": {
            "donor.publication_status": "New"
          }
        },
        { 
          "match_phrase": {
            "donor.publication_status": "QA"
          }
        },
      ],
    }
  }
}


BASE_URL = "https://search.api.hubmapconsortium.org/v3/" 
endpoint = "search"
URL = BASE_URL + endpoint
resp = requests.post(URL, headers=headers, json=DSL_Query)

# %%
resp.json()
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [],
#   'max_score': None,
#   'total': {'relation': 'eq', 'value': 0}},
#  'timed_out': False,
#  'took': 1}

# %% [markdown]
# ##### Using Entity API

# %%
nexus_token = "Agd373rPmMWnXaWYV7K61jvMOEvjkYBVaK9oEwPvywyxkrlvy0UXCopKXywKJopxG3vV8MgG3wv4ODuMX0oBrCrPa8"
headers = {
    # 'accept': 'application/json',
    # 'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + nexus_token
}

BASE_URL = "https://entity.api.hubmapconsortium.org/"
endpoint = "datasets/prov-info"
params = {
    "format" : "json"
}
URL = BASE_URL + endpoint
resp = requests.get(URL, headers=headers, params=params)

# %%
resp.json()
# Out:
# [{'dataset_created_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_data_types': ['Autofluorescence Microscopy'],
#   'dataset_date_time_created': '2022-10-11 17:57:39',
#   'dataset_date_time_modified': '2022-10-11 17:57:39',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM858.MFFT.638',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/34056fbd3adb97f19a653390869ea1de',
#   'dataset_status': 'New',
#   'dataset_uuid': '34056fbd3adb97f19a653390869ea1de',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM493.PMZQ.923'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/93b51537a638fb29c7df9584beeecd4b'],
#   'first_sample_submission_id': ['VAN0007-LK-202-9'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['93b51537a638fb29c7df9584beeecd4b'],
#   'lab_id_or_name': None,
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': [],
#   'processed_dataset_portal_url': [],
#   'processed_dataset_status': [],
#   'processed_dataset_uuid': [],
#   'rui_location_hubmap_id': ['HBM469.KBFN.774'],
#   'rui_location_submission_id': ['VAN0007-LK-202'],
#   'rui_location_uuid': ['088adc477043f3970311122b0365bba8'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_data_types': ['Autofluorescence Microscopy'],
#   'dataset_date_time_created': '2022-10-11 17:57:09',
#   'dataset_date_time_modified': '2022-10-11 17:57:09',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM958.PNXC.824',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/9b82e4f2bd429e49ec632c3132d380a5',
#   'dataset_status': 'New',
#   'dataset_uuid': '9b82e4f2bd429e49ec632c3132d380a5',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM493.PMZQ.923'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/93b51537a638fb29c7df9584beeecd4b'],
#   'first_sample_submission_id': ['VAN0007-LK-202-9'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['93b51537a638fb29c7df9584beeecd4b'],
#   'lab_id_or_name': None,
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': [],
#   'processed_dataset_portal_url': [],
#   'processed_dataset_status': [],
#   'processed_dataset_uuid': [],
#   'rui_location_hubmap_id': ['HBM469.KBFN.774'],
#   'rui_location_submission_id': ['VAN0007-LK-202'],
#   'rui_location_uuid': ['088adc477043f3970311122b0365bba8'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_data_types': ['Autofluorescence Microscopy'],
#   'dataset_date_time_created': '2022-10-03 16:31:04',
#   'dataset_date_time_modified': '2023-02-20 16:29:43',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM246.JNGT.269',
#   'dataset_modified_by_email': 'jamie.l.allen@vanderbilt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/a7446cfb37adfac308eb69ec307dd69a',
#   'dataset_status': 'QA',
#   'dataset_uuid': 'a7446cfb37adfac308eb69ec307dd69a',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM548.LXLL.834'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/3b65005eac9d19d02c0f688327328781'],
#   'first_sample_submission_id': ['VAN0007-LK-202-20'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['3b65005eac9d19d02c0f688327328781'],
#   'lab_id_or_name': None,
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM949.VHCW.597'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/4176c40f5512a6e8fbc9c6975ddec2b5'],
#   'processed_dataset_status': ['QA'],
#   'processed_dataset_uuid': ['4176c40f5512a6e8fbc9c6975ddec2b5'],
#   'rui_location_hubmap_id': ['HBM469.KBFN.774'],
#   'rui_location_submission_id': ['VAN0007-LK-202'],
#   'rui_location_uuid': ['088adc477043f3970311122b0365bba8'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_data_types': ['Autofluorescence Microscopy'],
#   'dataset_date_time_created': '2022-10-03 18:17:22',
#   'dataset_date_time_modified': '2023-02-20 15:53:10',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM966.RLGZ.875',
#   'dataset_modified_by_email': 'jamie.l.allen@vanderbilt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/d7c35eb4231b8dea0a2a559c55d3afd3',
#   'dataset_status': 'QA',
#   'dataset_uuid': 'd7c35eb4231b8dea0a2a559c55d3afd3',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM723.MRBD.876'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/699857c48b1a8a0dfe96922fb5137ec2'],
#   'first_sample_submission_id': ['VAN0007-LK-202-13'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['699857c48b1a8a0dfe96922fb5137ec2'],
#   'lab_id_or_name': None,
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM944.HFVH.375'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/a549c703ceccc91c29e9db3853d41a4b'],
#   'processed_dataset_status': ['QA'],
#   'processed_dataset_uuid': ['a549c703ceccc91c29e9db3853d41a4b'],
#   'rui_location_hubmap_id': ['HBM469.KBFN.774'],
#   'rui_location_submission_id': ['VAN0007-LK-202'],
#   'rui_location_uuid': ['088adc477043f3970311122b0365bba8'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_data_types': ['MALDI IMS'],
#   'dataset_date_time_created': '2023-01-12 14:46:09',
#   'dataset_date_time_modified': '2023-01-12 16:41:35',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM453.RTXK.849',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/18e070c6e64dd701705e09b54b4eed4d',
#   'dataset_status': 'QA',
#   'dataset_uuid': '18e070c6e64dd701705e09b54b4eed4d',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM723.MRBD.876'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/699857c48b1a8a0dfe96922fb5137ec2'],
#   'first_sample_submission_id': ['VAN0007-LK-202-13'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['699857c48b1a8a0dfe96922fb5137ec2'],
#   'lab_id_or_name': None,
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM938.WTJG.543'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/44ba28c5417f8fbf9c3cb74422ed8f61'],
#   'processed_dataset_status': ['Error'],
#   'processed_dataset_uuid': ['44ba28c5417f8fbf9c3cb74422ed8f61'],
#   'rui_location_hubmap_id': ['HBM469.KBFN.774'],
#   'rui_location_submission_id': ['VAN0007-LK-202'],
#   'rui_location_uuid': ['088adc477043f3970311122b0365bba8'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_data_types': ['MALDI IMS'],
#   'dataset_date_time_created': '2023-01-12 15:30:44',
#   'dataset_date_time_modified': '2023-01-12 15:30:44',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM777.STQB.672',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/2fdbf2be6b297eb1951b11db5b79cadb',
#   'dataset_status': 'New',
#   'dataset_uuid': '2fdbf2be6b297eb1951b11db5b79cadb',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM723.MRBD.876'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/699857c48b1a8a0dfe96922fb5137ec2'],
#   'first_sample_submission_id': ['VAN0007-LK-202-13'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['699857c48b1a8a0dfe96922fb5137ec2'],
#   'lab_id_or_name': None,
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': [],
#   'processed_dataset_portal_url': [],
#   'processed_dataset_status': [],
#   'processed_dataset_uuid': [],
#   'rui_location_hubmap_id': ['HBM469.KBFN.774'],
#   'rui_location_submission_id': ['VAN0007-LK-202'],
#   'rui_location_uuid': ['088adc477043f3970311122b0365bba8'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'spraggj@vanderbilt.edu',
#   'dataset_data_types': ['PAS Stained Microscopy'],
#   'dataset_date_time_created': '2020-05-18 01:52:12',
#   'dataset_date_time_modified': '2022-02-12 04:35:54',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM362.PTQJ.743',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/7eef1634020f429f9855ff319ff0c65e',
#   'dataset_status': 'Published',
#   'dataset_uuid': '7eef1634020f429f9855ff319ff0c65e',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM953.SQPG.639'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/b8f8acd3659ac151092f6a8346150a06'],
#   'first_sample_submission_id': ['VAN0007-LK-203-103'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['b8f8acd3659ac151092f6a8346150a06'],
#   'lab_id_or_name': 'Periodic acid-Schiff Stained Microscopy of Human Kidney Tissue',
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM829.NPFP.957'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/23f1637a0a90fdd2a8feece44d00c22e'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['23f1637a0a90fdd2a8feece44d00c22e'],
#   'rui_location_hubmap_id': ['HBM579.GDJB.858'],
#   'rui_location_submission_id': ['VAN0007-LK-203'],
#   'rui_location_uuid': ['3a4b8bfca8e842cae400f49e19987c7c'],
#   'sample_metadata_hubmap_id': ['HBM579.GDJB.858'],
#   'sample_metadata_submission_id': ['VAN0007-LK-203'],
#   'sample_metadata_uuid': ['3a4b8bfca8e842cae400f49e19987c7c']},
#  {'dataset_created_by_email': 'spraggj@vanderbilt.edu',
#   'dataset_data_types': ['MALDI IMS'],
#   'dataset_date_time_created': '2020-05-18 01:52:11',
#   'dataset_date_time_modified': '2022-02-12 04:54:32',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM739.JKQC.464',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/1d1a8376b558398588f92688314f23c5',
#   'dataset_status': 'Published',
#   'dataset_uuid': '1d1a8376b558398588f92688314f23c5',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM953.SQPG.639'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/b8f8acd3659ac151092f6a8346150a06'],
#   'first_sample_submission_id': ['VAN0007-LK-203-103'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['b8f8acd3659ac151092f6a8346150a06'],
#   'lab_id_or_name': 'MALDI Imaging Mass Spectrometry of Human Kidney Tissue - Positive Ion Mode',
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM478.ZBVG.942'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/a9e97dfb17c7fe08a9c4590318955095'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['a9e97dfb17c7fe08a9c4590318955095'],
#   'rui_location_hubmap_id': ['HBM579.GDJB.858'],
#   'rui_location_submission_id': ['VAN0007-LK-203'],
#   'rui_location_uuid': ['3a4b8bfca8e842cae400f49e19987c7c'],
#   'sample_metadata_hubmap_id': ['HBM579.GDJB.858'],
#   'sample_metadata_submission_id': ['VAN0007-LK-203'],
#   'sample_metadata_uuid': ['3a4b8bfca8e842cae400f49e19987c7c']},
#  {'dataset_created_by_email': 'spraggj@vanderbilt.edu',
#   'dataset_data_types': ['MALDI IMS'],
#   'dataset_date_time_created': '2020-05-18 01:52:09',
#   'dataset_date_time_modified': '2022-02-12 04:44:00',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM889.NSRP.924',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/d4fae29feb0215a11b6e4d3072107e09',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'd4fae29feb0215a11b6e4d3072107e09',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM953.SQPG.639'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/b8f8acd3659ac151092f6a8346150a06'],
#   'first_sample_submission_id': ['VAN0007-LK-203-103'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['b8f8acd3659ac151092f6a8346150a06'],
#   'lab_id_or_name': 'MALDI Imaging Mass Spectrometry of Human Kidney Tissue - Positive Ion Mode',
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM384.WVWZ.264'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/72d7f6895a34be4e0f43df278c675da2'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['72d7f6895a34be4e0f43df278c675da2'],
#   'rui_location_hubmap_id': ['HBM579.GDJB.858'],
#   'rui_location_submission_id': ['VAN0007-LK-203'],
#   'rui_location_uuid': ['3a4b8bfca8e842cae400f49e19987c7c'],
#   'sample_metadata_hubmap_id': ['HBM579.GDJB.858'],
#   'sample_metadata_submission_id': ['VAN0007-LK-203'],
#   'sample_metadata_uuid': ['3a4b8bfca8e842cae400f49e19987c7c']},
#  {'dataset_created_by_email': 'spraggj@vanderbilt.edu',
#   'dataset_data_types': ['Autofluorescence Microscopy'],
#   'dataset_date_time_created': '2020-05-18 01:52:08',
#   'dataset_date_time_modified': '2022-02-12 15:19:33',
#   'dataset_group_name': 'Vanderbilt TMC',
#   'dataset_group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#   'dataset_hubmap_id': 'HBM529.NGCG.277',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/0a6f5c1afbcc31622eb34daf88c2c016',
#   'dataset_status': 'Published',
#   'dataset_uuid': '0a6f5c1afbcc31622eb34daf88c2c016',
#   'donor_group_name': ['Vanderbilt TMC'],
#   'donor_hubmap_id': ['HBM758.JRSC.348'],
#   'donor_submission_id': ['VAN0007'],
#   'donor_uuid': ['96a667104f92a38f5d4f97c38d94e738'],
#   'first_sample_hubmap_id': ['HBM953.SQPG.639'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/b8f8acd3659ac151092f6a8346150a06'],
#   'first_sample_submission_id': ['VAN0007-LK-203-103'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['b8f8acd3659ac151092f6a8346150a06'],
#   'lab_id_or_name': 'Autofluorescence Microscopy of Human Kidney Tissue',
#   'organ_hubmap_id': ['HBM865.MWHF.489'],
#   'organ_submission_id': ['VAN0007-LK'],
#   'organ_type': ['kidney (left)'],
#   'organ_uuid': ['8e90c3bfa86c1a363dbcfe39d18f38b6'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM394.CDWG.768'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/d0b944edce4f7fc2a61321d5dc915a72'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['d0b944edce4f7fc2a61321d5dc915a72'],
#   'rui_location_hubmap_id': ['HBM579.GDJB.858'],
#   'rui_location_submission_id': ['VAN0007-LK-203'],
#   'rui_location_uuid': ['3a4b8bfca8e842cae400f49e19987c7c'],
#   'sample_metadata_hubmap_id': ['HBM579.GDJB.858'],
#   'sample_metadata_submission_id': ['VAN0007-LK-203'],
#   'sample_metadata_uuid': ['3a4b8bfca8e842cae400f49e19987c7c']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['scRNA-seq (10x Genomics v3)'],
#   'dataset_date_time_created': '2019-12-18 20:01:10',
#   'dataset_date_time_modified': '2022-02-11 19:53:46',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM472.NTNN.543',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/3683b49e27133c064ccbd59ff9723e7c',
#   'dataset_status': 'Published',
#   'dataset_uuid': '3683b49e27133c064ccbd59ff9723e7c',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM259.JWWT.889'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/ed12b3e37fc8dcc4287f4f209eef9c4b'],
#   'first_sample_submission_id': ['UFL0002-SP-2-2'],
#   'first_sample_type': ['suspension'],
#   'first_sample_uuid': ['ed12b3e37fc8dcc4287f4f209eef9c4b'],
#   'lab_id_or_name': 'HBMP2_spleen_2',
#   'organ_hubmap_id': ['HBM369.DGXL.358'],
#   'organ_submission_id': ['UFL0002-SP'],
#   'organ_type': ['spleen'],
#   'organ_uuid': ['dd69e57643816e065ab04a8eec2b71b8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM536.GZQR.922'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/35a639b983ff85728bdb3cbe0eac360a'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['35a639b983ff85728bdb3cbe0eac360a'],
#   'rui_location_hubmap_id': ['HBM259.JWWT.889'],
#   'rui_location_submission_id': ['UFL0002-SP-2-2'],
#   'rui_location_uuid': ['ed12b3e37fc8dcc4287f4f209eef9c4b'],
#   'sample_metadata_hubmap_id': ['HBM259.JWWT.889'],
#   'sample_metadata_submission_id': ['UFL0002-SP-2-2'],
#   'sample_metadata_uuid': ['ed12b3e37fc8dcc4287f4f209eef9c4b']},
#  {'dataset_created_by_email': 'hakimianh13@ufl.edu',
#   'dataset_data_types': ['CODEX'],
#   'dataset_date_time_created': '2022-03-18 18:51:24',
#   'dataset_date_time_modified': '2022-06-27 17:29:02',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM968.CJLB.479',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/efeae1a9895b88a4ccdbfa35dc98fdf2',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'efeae1a9895b88a4ccdbfa35dc98fdf2',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM688.DQGM.882'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/8d912783076037b57986afa62162f41d'],
#   'first_sample_submission_id': ['UFL0002-SP-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['8d912783076037b57986afa62162f41d'],
#   'lab_id_or_name': 'CX_19-002_SP_CC2-A28',
#   'organ_hubmap_id': ['HBM369.DGXL.358'],
#   'organ_submission_id': ['UFL0002-SP'],
#   'organ_type': ['spleen'],
#   'organ_uuid': ['dd69e57643816e065ab04a8eec2b71b8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM594.PWXG.764'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/9358adf4674413a0e2ef1a970b66714e'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['9358adf4674413a0e2ef1a970b66714e'],
#   'rui_location_hubmap_id': ['HBM688.DQGM.882', 'HBM338.TDRB.772'],
#   'rui_location_submission_id': ['UFL0002-SP-2-4-1', 'UFL0002-SP-2-4'],
#   'rui_location_uuid': ['8d912783076037b57986afa62162f41d',
#    '6e23ef9bbe7940257bbc9383bf05b546'],
#   'sample_metadata_hubmap_id': ['HBM688.DQGM.882'],
#   'sample_metadata_submission_id': ['UFL0002-SP-2-4-1'],
#   'sample_metadata_uuid': ['8d912783076037b57986afa62162f41d']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['CODEX'],
#   'dataset_date_time_created': '2020-02-18 16:16:09',
#   'dataset_date_time_modified': '2022-02-11 19:59:52',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM987.XGTH.368',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/e0ba24d0c4dab528e46aab3f67a1aae8',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'e0ba24d0c4dab528e46aab3f67a1aae8',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM688.DQGM.882'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/8d912783076037b57986afa62162f41d'],
#   'first_sample_submission_id': ['UFL0002-SP-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['8d912783076037b57986afa62162f41d'],
#   'lab_id_or_name': '19-002_spleen_CC2-A',
#   'organ_hubmap_id': ['HBM369.DGXL.358'],
#   'organ_submission_id': ['UFL0002-SP'],
#   'organ_type': ['spleen'],
#   'organ_uuid': ['dd69e57643816e065ab04a8eec2b71b8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM732.GQLB.743', 'HBM696.DSTM.687'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/bf1e01bb3b747976fe59e2286448efeb',
#    'https://portal.hubmapconsortium.org/browse/dataset/29a16817f1337e0a0da1c3454ff99fe7'],
#   'processed_dataset_status': ['Published', 'Published'],
#   'processed_dataset_uuid': ['bf1e01bb3b747976fe59e2286448efeb',
#    '29a16817f1337e0a0da1c3454ff99fe7'],
#   'rui_location_hubmap_id': ['HBM688.DQGM.882', 'HBM338.TDRB.772'],
#   'rui_location_submission_id': ['UFL0002-SP-2-4-1', 'UFL0002-SP-2-4'],
#   'rui_location_uuid': ['8d912783076037b57986afa62162f41d',
#    '6e23ef9bbe7940257bbc9383bf05b546'],
#   'sample_metadata_hubmap_id': ['HBM688.DQGM.882'],
#   'sample_metadata_submission_id': ['UFL0002-SP-2-4-1'],
#   'sample_metadata_uuid': ['8d912783076037b57986afa62162f41d']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['CODEX'],
#   'dataset_date_time_created': '2019-12-20 19:41:09',
#   'dataset_date_time_modified': '2022-02-11 19:56:35',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM558.SRZG.629',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/b7a2c05fdd9ddd0c83c9786ede98a24e',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'b7a2c05fdd9ddd0c83c9786ede98a24e',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM827.VSGK.934'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/3d0e6983c0c7e8354cb4bded851b15b1'],
#   'first_sample_submission_id': ['UFL0002-SP-3-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['3d0e6983c0c7e8354cb4bded851b15b1'],
#   'lab_id_or_name': '19-002-SP-CC3-C',
#   'organ_hubmap_id': ['HBM369.DGXL.358'],
#   'organ_submission_id': ['UFL0002-SP'],
#   'organ_type': ['spleen'],
#   'organ_uuid': ['dd69e57643816e065ab04a8eec2b71b8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM542.THBC.733', 'HBM739.KJCB.594'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/37581089fc2b39aab823a3093bc1381b',
#    'https://portal.hubmapconsortium.org/browse/dataset/cd345bb3ea5e91ea915ac8e0e66d235b'],
#   'processed_dataset_status': ['Published', 'Published'],
#   'processed_dataset_uuid': ['37581089fc2b39aab823a3093bc1381b',
#    'cd345bb3ea5e91ea915ac8e0e66d235b'],
#   'rui_location_hubmap_id': ['HBM827.VSGK.934', 'HBM223.WQVG.533'],
#   'rui_location_submission_id': ['UFL0002-SP-3-4-1', 'UFL0002-SP-3-4'],
#   'rui_location_uuid': ['3d0e6983c0c7e8354cb4bded851b15b1',
#    '19d486f0d168ef0d02291972fb669996'],
#   'sample_metadata_hubmap_id': ['HBM827.VSGK.934'],
#   'sample_metadata_submission_id': ['UFL0002-SP-3-4-1'],
#   'sample_metadata_uuid': ['3d0e6983c0c7e8354cb4bded851b15b1']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['scRNA-seq (10x Genomics v3)'],
#   'dataset_date_time_created': '2019-12-18 19:58:44',
#   'dataset_date_time_modified': '2022-02-11 19:53:52',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM373.RTKK.586',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/4081680ef553db5f91fb3587dde595b6',
#   'dataset_status': 'Published',
#   'dataset_uuid': '4081680ef553db5f91fb3587dde595b6',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM733.NFWS.792'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/cc85586061c13a5fb6adf72c75a32cf9'],
#   'first_sample_submission_id': ['UFL0002-TH-2-1'],
#   'first_sample_type': ['suspension'],
#   'first_sample_uuid': ['cc85586061c13a5fb6adf72c75a32cf9'],
#   'lab_id_or_name': 'HBMP2_thymus_2',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM538.PHSC.677'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/3ac0768d61c6c84f0ec59d766e123e05'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['3ac0768d61c6c84f0ec59d766e123e05'],
#   'rui_location_hubmap_id': ['HBM733.NFWS.792'],
#   'rui_location_submission_id': ['UFL0002-TH-2-1'],
#   'rui_location_uuid': ['cc85586061c13a5fb6adf72c75a32cf9'],
#   'sample_metadata_hubmap_id': ['HBM733.NFWS.792'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-1'],
#   'sample_metadata_uuid': ['cc85586061c13a5fb6adf72c75a32cf9']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['CODEX'],
#   'dataset_date_time_created': '2020-02-21 15:26:23',
#   'dataset_date_time_modified': '2022-02-11 20:01:11',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM246.VPVL.879',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/776bd778f20409d8ce2dd8f5bf5789ae',
#   'dataset_status': 'Published',
#   'dataset_uuid': '776bd778f20409d8ce2dd8f5bf5789ae',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM663.CXTS.935'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/0ccf43ecc685e2ce2bd339fb87a240a2'],
#   'first_sample_submission_id': ['UFL0002-TH-2-3-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['0ccf43ecc685e2ce2bd339fb87a240a2'],
#   'lab_id_or_name': '19-002_thymus_CC2-C',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM387.QZQK.847',
#    'HBM335.MZDX.889',
#    'HBM366.XKPX.554'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/0cc0ba032f21cf15af1290dd28bf1bd3',
#    'https://portal.hubmapconsortium.org/browse/dataset/d7d28ada35262993a03f4dc43e0b3cc4',
#    'https://portal.hubmapconsortium.org/browse/dataset/b69d1e2ad1bf1455eee991fce301b191'],
#   'processed_dataset_status': ['QA', 'Error', 'Published'],
#   'processed_dataset_uuid': ['0cc0ba032f21cf15af1290dd28bf1bd3',
#    'd7d28ada35262993a03f4dc43e0b3cc4',
#    'b69d1e2ad1bf1455eee991fce301b191'],
#   'rui_location_hubmap_id': ['HBM663.CXTS.935', 'HBM389.MGXT.546'],
#   'rui_location_submission_id': ['UFL0002-TH-2-3-1', 'UFL0002-TH-2-3'],
#   'rui_location_uuid': ['0ccf43ecc685e2ce2bd339fb87a240a2',
#    '8914ee0fd2e790f56b722640397bfb4d'],
#   'sample_metadata_hubmap_id': ['HBM663.CXTS.935'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-3-1'],
#   'sample_metadata_uuid': ['0ccf43ecc685e2ce2bd339fb87a240a2']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['Imaging Mass Cytometry (2D)'],
#   'dataset_date_time_created': '2020-07-30 20:28:45',
#   'dataset_date_time_modified': '2022-02-11 19:54:26',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM256.TVMB.842',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/9a6403bb0423e62950926a7d4fdab45b',
#   'dataset_status': 'Published',
#   'dataset_uuid': '9a6403bb0423e62950926a7d4fdab45b',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM374.XJNM.984'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'first_sample_submission_id': ['UFL0002-TH-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'lab_id_or_name': '19-002-Thymus-CC2-D-R6',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM759.VWQB.343'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/912889b51fed4ac4fdf2d4d3c5550f72'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['912889b51fed4ac4fdf2d4d3c5550f72'],
#   'rui_location_hubmap_id': ['HBM374.XJNM.984', 'HBM247.KQXN.358'],
#   'rui_location_submission_id': ['UFL0002-TH-2-4-1', 'UFL0002-TH-2-4'],
#   'rui_location_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5',
#    '117f50e0c71afde9435365f1a7ebe612'],
#   'sample_metadata_hubmap_id': ['HBM374.XJNM.984'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-4-1'],
#   'sample_metadata_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['Imaging Mass Cytometry (2D)'],
#   'dataset_date_time_created': '2020-07-30 20:28:32',
#   'dataset_date_time_modified': '2022-02-11 19:55:04',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM736.CMTG.482',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/989181f44061257701eca7c0b63e0f9f',
#   'dataset_status': 'Published',
#   'dataset_uuid': '989181f44061257701eca7c0b63e0f9f',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM374.XJNM.984'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'first_sample_submission_id': ['UFL0002-TH-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'lab_id_or_name': '19-002-Thymus-CC2-D-R2',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM436.KNLR.352'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/8c96b03e755858b34547dd1b315991df'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['8c96b03e755858b34547dd1b315991df'],
#   'rui_location_hubmap_id': ['HBM374.XJNM.984', 'HBM247.KQXN.358'],
#   'rui_location_submission_id': ['UFL0002-TH-2-4-1', 'UFL0002-TH-2-4'],
#   'rui_location_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5',
#    '117f50e0c71afde9435365f1a7ebe612'],
#   'sample_metadata_hubmap_id': ['HBM374.XJNM.984'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-4-1'],
#   'sample_metadata_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['Imaging Mass Cytometry (2D)'],
#   'dataset_date_time_created': '2020-07-30 20:28:42',
#   'dataset_date_time_modified': '2022-02-11 19:54:34',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM572.PHZP.966',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/45c5111e579800c021fd5dfaedc614c2',
#   'dataset_status': 'Published',
#   'dataset_uuid': '45c5111e579800c021fd5dfaedc614c2',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM374.XJNM.984'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'first_sample_submission_id': ['UFL0002-TH-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'lab_id_or_name': '19-002-Thymus-CC2-D-R5',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM927.CWBF.456'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/46a69f99d8793f9ddf8ee4a1dba5d0e3'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['46a69f99d8793f9ddf8ee4a1dba5d0e3'],
#   'rui_location_hubmap_id': ['HBM374.XJNM.984', 'HBM247.KQXN.358'],
#   'rui_location_submission_id': ['UFL0002-TH-2-4-1', 'UFL0002-TH-2-4'],
#   'rui_location_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5',
#    '117f50e0c71afde9435365f1a7ebe612'],
#   'sample_metadata_hubmap_id': ['HBM374.XJNM.984'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-4-1'],
#   'sample_metadata_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['Imaging Mass Cytometry (2D)'],
#   'dataset_date_time_created': '2020-07-30 20:28:40',
#   'dataset_date_time_modified': '2022-02-11 19:54:43',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM472.SZJZ.622',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/6618f3be3571e757aa473d1a3e60b356',
#   'dataset_status': 'Published',
#   'dataset_uuid': '6618f3be3571e757aa473d1a3e60b356',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM374.XJNM.984'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'first_sample_submission_id': ['UFL0002-TH-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'lab_id_or_name': '19-002-Thymus-CC2-D-R4',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM345.CXVP.994'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/5f13623f8b4a51758d5216404a3ea862'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['5f13623f8b4a51758d5216404a3ea862'],
#   'rui_location_hubmap_id': ['HBM374.XJNM.984', 'HBM247.KQXN.358'],
#   'rui_location_submission_id': ['UFL0002-TH-2-4-1', 'UFL0002-TH-2-4'],
#   'rui_location_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5',
#    '117f50e0c71afde9435365f1a7ebe612'],
#   'sample_metadata_hubmap_id': ['HBM374.XJNM.984'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-4-1'],
#   'sample_metadata_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['Imaging Mass Cytometry (2D)'],
#   'dataset_date_time_created': '2020-07-30 20:28:38',
#   'dataset_date_time_modified': '2022-02-11 19:54:51',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM262.HJSQ.643',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/49cf1e5fa366852bd2b73f0d8ea206f5',
#   'dataset_status': 'Published',
#   'dataset_uuid': '49cf1e5fa366852bd2b73f0d8ea206f5',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM374.XJNM.984'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'first_sample_submission_id': ['UFL0002-TH-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'lab_id_or_name': '19-002-Thymus-CC2-D-R3',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM273.PSKK.537'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/b5e993ba9f01b0f5b8d1b6f4fbabc60a'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['b5e993ba9f01b0f5b8d1b6f4fbabc60a'],
#   'rui_location_hubmap_id': ['HBM374.XJNM.984', 'HBM247.KQXN.358'],
#   'rui_location_submission_id': ['UFL0002-TH-2-4-1', 'UFL0002-TH-2-4'],
#   'rui_location_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5',
#    '117f50e0c71afde9435365f1a7ebe612'],
#   'sample_metadata_hubmap_id': ['HBM374.XJNM.984'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-4-1'],
#   'sample_metadata_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['Imaging Mass Cytometry (2D)'],
#   'dataset_date_time_created': '2019-12-20 22:28:11',
#   'dataset_date_time_modified': '2022-02-11 19:55:13',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM273.TDVP.568',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/2523d502e8bdd90d461aad4ac95a2172',
#   'dataset_status': 'Published',
#   'dataset_uuid': '2523d502e8bdd90d461aad4ac95a2172',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM374.XJNM.984'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'first_sample_submission_id': ['UFL0002-TH-2-4-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5'],
#   'lab_id_or_name': '19-002-Thymus-CC2-D-R1',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM633.GRZR.589'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/62536a0e88d9d071f5f0c5048848ed8c'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['62536a0e88d9d071f5f0c5048848ed8c'],
#   'rui_location_hubmap_id': ['HBM374.XJNM.984', 'HBM247.KQXN.358'],
#   'rui_location_submission_id': ['UFL0002-TH-2-4-1', 'UFL0002-TH-2-4'],
#   'rui_location_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5',
#    '117f50e0c71afde9435365f1a7ebe612'],
#   'sample_metadata_hubmap_id': ['HBM374.XJNM.984'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-4-1'],
#   'sample_metadata_uuid': ['06f2cc3fbcae1ceb3ea331e591f75ab5']},
#  {'dataset_created_by_email': 'hakimianh13@ufl.edu',
#   'dataset_data_types': ['Imaging Mass Cytometry (3D)'],
#   'dataset_date_time_created': '2021-02-18 18:57:40',
#   'dataset_date_time_modified': '2022-05-11 02:30:28',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM778.VHHR.349',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/cd880c54e0095bad5200397588eccf81',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'cd880c54e0095bad5200397588eccf81',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM292.MDGW.892'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/e15ce4762cb77e380ea66c9cb40d4c58'],
#   'first_sample_submission_id': ['UFL0002-TH-2-4-2'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['e15ce4762cb77e380ea66c9cb40d4c58'],
#   'lab_id_or_name': 'IMC_19002_TH_CC2D_3D',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM643.KVJB.282'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/e450e6cca3f5f832ff7286543b7d2253'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['e450e6cca3f5f832ff7286543b7d2253'],
#   'rui_location_hubmap_id': ['HBM247.KQXN.358'],
#   'rui_location_submission_id': ['UFL0002-TH-2-4'],
#   'rui_location_uuid': ['117f50e0c71afde9435365f1a7ebe612'],
#   'sample_metadata_hubmap_id': ['HBM292.MDGW.892'],
#   'sample_metadata_submission_id': ['UFL0002-TH-2-4-2'],
#   'sample_metadata_uuid': ['e15ce4762cb77e380ea66c9cb40d4c58']},
#  {'dataset_created_by_email': 'jesus.penalozaa@ufl.edu',
#   'dataset_data_types': ['CODEX'],
#   'dataset_date_time_created': '2019-12-20 19:23:08',
#   'dataset_date_time_modified': '2022-02-11 19:57:14',
#   'dataset_group_name': 'University of Florida TMC',
#   'dataset_group_uuid': '07a29e4c-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM339.XXWC.842',
#   'dataset_modified_by_email': 'ZHY19@pitt.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/e21e76dbfcf94f3de679a284c8aa9bd1',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'e21e76dbfcf94f3de679a284c8aa9bd1',
#   'donor_group_name': ['University of Florida TMC'],
#   'donor_hubmap_id': ['HBM638.SMWG.276'],
#   'donor_submission_id': ['UFL0002'],
#   'donor_uuid': ['3f66765e3561ee075f8b0d85c564b545'],
#   'first_sample_hubmap_id': ['HBM647.FPJZ.936'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/e33dbdec521d4ffe9958b2888c3c3a4b'],
#   'first_sample_submission_id': ['UFL0002-TH-2-5-1'],
#   'first_sample_type': ['section'],
#   'first_sample_uuid': ['e33dbdec521d4ffe9958b2888c3c3a4b'],
#   'lab_id_or_name': '19-002-TH-CC1-E',
#   'organ_hubmap_id': ['HBM585.FCXH.792'],
#   'organ_submission_id': ['UFL0002-TH'],
#   'organ_type': ['thymus'],
#   'organ_uuid': ['1b6c9bf4ce99f6b91e6b9af1a208b6a0'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM545.WPDT.262', 'HBM792.RMBS.929'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/6f74609152fe7fd81974b7452112d2e2',
# ...
#   'dataset_data_types': ['snRNA-seq (10x Genomics v3)'],
#   'dataset_date_time_created': '2022-03-08 22:06:07',
#   'dataset_date_time_modified': '2022-03-09 02:56:52',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM356.HJJX.599',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/9fa2b2339de24d99ded5ec66b6f414b8',
#   'dataset_status': 'QA',
#   'dataset_uuid': '9fa2b2339de24d99ded5ec66b6f414b8',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM463.FBXN.343'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/edd2898e222ee5103b97084e3a528fd8'],
#   'first_sample_submission_id': ['STAN0007-LI-1-1'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['edd2898e222ee5103b97084e3a528fd8'],
#   'lab_id_or_name': None,
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM685.MSCQ.978'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/69d175d24b6b3997cc99fa6531a5fbce'],
#   'processed_dataset_status': ['QA'],
#   'processed_dataset_uuid': ['69d175d24b6b3997cc99fa6531a5fbce'],
#   'rui_location_hubmap_id': ['HBM463.FBXN.343', 'HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1-1', 'STAN0007-LI-1'],
#   'rui_location_uuid': ['edd2898e222ee5103b97084e3a528fd8',
#    '2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': ['HBM463.FBXN.343'],
#   'sample_metadata_submission_id': ['STAN0007-LI-1-1'],
#   'sample_metadata_uuid': ['edd2898e222ee5103b97084e3a528fd8']},
#  {'dataset_created_by_email': 'Daniel.cotter@stanford.edu',
#   'dataset_data_types': ['CODEX'],
#   'dataset_date_time_created': '2021-03-13 03:32:07',
#   'dataset_date_time_modified': '2022-09-08 15:57:20',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM938.KMNW.825',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/c5334b682758b141c481f87ae010b537',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'c5334b682758b141c481f87ae010b537',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM463.FBXN.343'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/edd2898e222ee5103b97084e3a528fd8'],
#   'first_sample_submission_id': ['STAN0007-LI-1-1'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['edd2898e222ee5103b97084e3a528fd8'],
#   'lab_id_or_name': 'B004-A-204-LargeIntestine-Ascending-CODEX',
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM657.JVPV.825',
#    'HBM498.MPZW.638',
#    'HBM882.DVPN.929',
#    'HBM575.BGCM.622',
#    'HBM238.NTPN.728'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/76d3efd17b6fc83aaac13e961824c5ae',
#    'https://portal.hubmapconsortium.org/browse/dataset/32ce4bd723563584d07fe726809253bd',
#    'https://portal.hubmapconsortium.org/browse/dataset/fdec175ea8d183edac01cd40398c39c2',
#    'https://portal.hubmapconsortium.org/browse/dataset/68b011b72ebf26b6e014d2e300007be0',
#    'https://portal.hubmapconsortium.org/browse/dataset/b179bfe63cc32d912ed1a995ab06d446'],
#   'processed_dataset_status': ['QA', 'QA', 'Error', 'Error', 'QA'],
#   'processed_dataset_uuid': ['76d3efd17b6fc83aaac13e961824c5ae',
#    '32ce4bd723563584d07fe726809253bd',
#    'fdec175ea8d183edac01cd40398c39c2',
#    '68b011b72ebf26b6e014d2e300007be0',
#    'b179bfe63cc32d912ed1a995ab06d446'],
#   'rui_location_hubmap_id': ['HBM463.FBXN.343', 'HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1-1', 'STAN0007-LI-1'],
#   'rui_location_uuid': ['edd2898e222ee5103b97084e3a528fd8',
#    '2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': ['HBM463.FBXN.343'],
#   'sample_metadata_submission_id': ['STAN0007-LI-1-1'],
#   'sample_metadata_uuid': ['edd2898e222ee5103b97084e3a528fd8']},
#  {'dataset_created_by_email': 'Daniel.cotter@stanford.edu',
#   'dataset_data_types': ['snATAC-seq'],
#   'dataset_date_time_created': '2021-02-16 19:52:41',
#   'dataset_date_time_modified': '2021-06-07 22:14:41',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM397.SHGQ.476',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/889cc388af2a79caa599432b0d6318c5',
#   'dataset_status': 'Published',
#   'dataset_uuid': '889cc388af2a79caa599432b0d6318c5',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM463.FBXN.343'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/edd2898e222ee5103b97084e3a528fd8'],
#   'first_sample_submission_id': ['STAN0007-LI-1-1'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['edd2898e222ee5103b97084e3a528fd8'],
#   'lab_id_or_name': 'B004-A-204-LargeIntestine-Ascending-scATACseq',
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM233.XWSR.882'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/a722cc2baba405194d680bb83597aa4b'],
#   'processed_dataset_status': ['Error'],
#   'processed_dataset_uuid': ['a722cc2baba405194d680bb83597aa4b'],
#   'rui_location_hubmap_id': ['HBM463.FBXN.343', 'HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1-1', 'STAN0007-LI-1'],
#   'rui_location_uuid': ['edd2898e222ee5103b97084e3a528fd8',
#    '2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': ['HBM463.FBXN.343'],
#   'sample_metadata_submission_id': ['STAN0007-LI-1-1'],
#   'sample_metadata_uuid': ['edd2898e222ee5103b97084e3a528fd8']},
#  {'dataset_created_by_email': 'Daniel.cotter@stanford.edu',
#   'dataset_data_types': ['snRNA-seq (10x Genomics v3)'],
#   'dataset_date_time_created': '2021-02-16 22:00:37',
#   'dataset_date_time_modified': '2021-04-21 22:24:34',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM998.WTJK.564',
#   'dataset_modified_by_email': 'hubmap@hubmapconsortium.org',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/f1937797246fa4592bff6166d7666de5',
#   'dataset_status': 'Published',
#   'dataset_uuid': 'f1937797246fa4592bff6166d7666de5',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM463.FBXN.343'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/edd2898e222ee5103b97084e3a528fd8'],
#   'first_sample_submission_id': ['STAN0007-LI-1-1'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['edd2898e222ee5103b97084e3a528fd8'],
#   'lab_id_or_name': 'B004-A-204-LargeIntestine-Ascending-scRNAseq',
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': ['HBM962.KQLZ.422'],
#   'processed_dataset_portal_url': ['https://portal.hubmapconsortium.org/browse/dataset/04968c1fe0149ee367b0e53af55763e4'],
#   'processed_dataset_status': ['Published'],
#   'processed_dataset_uuid': ['04968c1fe0149ee367b0e53af55763e4'],
#   'rui_location_hubmap_id': ['HBM463.FBXN.343', 'HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1-1', 'STAN0007-LI-1'],
#   'rui_location_uuid': ['edd2898e222ee5103b97084e3a528fd8',
#    '2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': ['HBM463.FBXN.343'],
#   'sample_metadata_submission_id': ['STAN0007-LI-1-1'],
#   'sample_metadata_uuid': ['edd2898e222ee5103b97084e3a528fd8']},
#  {'dataset_created_by_email': 'jw1d@andrew.cmu.edu',
#   'dataset_data_types': ['LC-MS'],
#   'dataset_date_time_created': '2022-03-22 22:37:00',
#   'dataset_date_time_modified': '2023-02-17 21:26:07',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM832.NBRH.626',
#   'dataset_modified_by_email': 'Daniel.cotter@stanford.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/58e6b847238123a31a68928a4d667197',
#   'dataset_status': 'QA',
#   'dataset_uuid': '58e6b847238123a31a68928a4d667197',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM546.XBKB.885'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/450e073aab976738e7cd478063b5a93d'],
#   'first_sample_submission_id': ['STAN0007-LI-1-2'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['450e073aab976738e7cd478063b5a93d'],
#   'lab_id_or_name': 'B004-A-201-Large Intestine-Ascending-pRPLC',
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': [],
#   'processed_dataset_portal_url': [],
#   'processed_dataset_status': [],
#   'processed_dataset_uuid': [],
#   'rui_location_hubmap_id': ['HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1'],
#   'rui_location_uuid': ['2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'jw1d@andrew.cmu.edu',
#   'dataset_data_types': ['LC-MS'],
#   'dataset_date_time_created': '2022-03-22 22:35:53',
#   'dataset_date_time_modified': '2023-02-17 21:25:40',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM679.HJLT.388',
#   'dataset_modified_by_email': 'Daniel.cotter@stanford.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/94aeac2dd166144b7188c6e2b1c3c542',
#   'dataset_status': 'QA',
#   'dataset_uuid': '94aeac2dd166144b7188c6e2b1c3c542',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM546.XBKB.885'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/450e073aab976738e7cd478063b5a93d'],
#   'first_sample_submission_id': ['STAN0007-LI-1-2'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['450e073aab976738e7cd478063b5a93d'],
#   'lab_id_or_name': 'B004-A-201-Large Intestine-Ascending-nRPLC',
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': [],
#   'processed_dataset_portal_url': [],
#   'processed_dataset_status': [],
#   'processed_dataset_uuid': [],
#   'rui_location_hubmap_id': ['HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1'],
#   'rui_location_uuid': ['2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'jw1d@andrew.cmu.edu',
#   'dataset_data_types': ['LC-MS'],
#   'dataset_date_time_created': '2022-03-22 22:36:26',
#   'dataset_date_time_modified': '2023-02-17 21:25:18',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM355.MXVH.487',
#   'dataset_modified_by_email': 'Daniel.cotter@stanford.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/aa637516132ad79fe7df054b52147495',
#   'dataset_status': 'QA',
#   'dataset_uuid': 'aa637516132ad79fe7df054b52147495',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM546.XBKB.885'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/450e073aab976738e7cd478063b5a93d'],
#   'first_sample_submission_id': ['STAN0007-LI-1-2'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['450e073aab976738e7cd478063b5a93d'],
#   'lab_id_or_name': 'B004-A-201-Large Intestine-Ascending-pHILIC',
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': [],
#   'processed_dataset_portal_url': [],
#   'processed_dataset_status': [],
#   'processed_dataset_uuid': [],
#   'rui_location_hubmap_id': ['HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1'],
#   'rui_location_uuid': ['2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  {'dataset_created_by_email': 'jw1d@andrew.cmu.edu',
#   'dataset_data_types': ['LC-MS'],
#   'dataset_date_time_created': '2022-03-22 22:35:21',
#   'dataset_date_time_modified': '2023-02-17 21:24:58',
#   'dataset_group_name': 'Stanford TMC',
#   'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#   'dataset_hubmap_id': 'HBM893.GHBZ.726',
#   'dataset_modified_by_email': 'Daniel.cotter@stanford.edu',
#   'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/06f672a6fc7ca03d92583055a35c8148',
#   'dataset_status': 'QA',
#   'dataset_uuid': '06f672a6fc7ca03d92583055a35c8148',
#   'donor_group_name': ['Stanford TMC'],
#   'donor_hubmap_id': ['HBM694.QDFG.746'],
#   'donor_submission_id': ['STAN0007'],
#   'donor_uuid': ['d3ad6409d2ad37ef7dbcc90ccc199f68'],
#   'first_sample_hubmap_id': ['HBM546.XBKB.885'],
#   'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/450e073aab976738e7cd478063b5a93d'],
#   'first_sample_submission_id': ['STAN0007-LI-1-2'],
#   'first_sample_type': ['block'],
#   'first_sample_uuid': ['450e073aab976738e7cd478063b5a93d'],
#   'lab_id_or_name': 'B004-A-201-Large Intestine-Ascending-nHILIC',
#   'organ_hubmap_id': ['HBM798.JCWT.636'],
#   'organ_submission_id': ['STAN0007-LI'],
#   'organ_type': ['large intestine'],
#   'organ_uuid': ['cb53dd247ec7e651161932fde83b4ca8'],
#   'previous_version_hubmap_ids': [],
#   'processed_dataset_hubmap_id': [],
#   'processed_dataset_portal_url': [],
#   'processed_dataset_status': [],
#   'processed_dataset_uuid': [],
#   'rui_location_hubmap_id': ['HBM896.ZPRW.239'],
#   'rui_location_submission_id': ['STAN0007-LI-1'],
#   'rui_location_uuid': ['2c4ed25579a369af5ae8f7523038235f'],
#   'sample_metadata_hubmap_id': [],
#   'sample_metadata_submission_id': [],
#   'sample_metadata_uuid': []},
#  ...]

# %%
dt_uuid_set = set([dt["dataset_uuid"] for dt in resp.json()])

# %%
len(dt_uuid_set)
# Out:
# 2137

# %%
set(all_dataset_metadata.keys()).__len__()
# Out:
# 1330

# %%
len(dt_uuid_set.intersection(set(all_dataset_metadata.keys())))
# Out:
# 924

# %%
len(set(all_dataset_metadata.keys()) - dt_uuid_set)
# Out:
# 406

# %%
nexus_token = "Agd373rPmMWnXaWYV7K61jvMOEvjkYBVaK9oEwPvywyxkrlvy0UXCopKXywKJopxG3vV8MgG3wv4ODuMX0oBrCrPa8"
headers = {
    # 'accept': 'application/json',
    # 'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + nexus_token
}
ID = list(dt_uuid_set)[0]

BASE_URL = "https://entity.api.hubmapconsortium.org/"
endpoint = f"datasets/{ID}/prov-info"
params = {
    "format" : "json",
    "id" : ID,
}
URL = BASE_URL + endpoint
resp = requests.get(URL, headers=headers, params=params)

# %%
resp.json()
# Out:
# {'dataset_created_by_email': 'Daniel.cotter@stanford.edu',
#  'dataset_data_types': ['CODEX'],
#  'dataset_date_time_created': '2022-08-30 20:08:04',
#  'dataset_date_time_modified': '2022-08-30 20:08:04',
#  'dataset_group_name': 'Stanford TMC',
#  'dataset_group_uuid': 'def5fd76-ed43-11e8-b56a-0e8017bdda58',
#  'dataset_hubmap_id': 'HBM285.VFDT.966',
#  'dataset_modified_by_email': 'Daniel.cotter@stanford.edu',
#  'dataset_portal_url': 'https://portal.hubmapconsortium.org/browse/dataset/7034950e109586361e73c1b9ddb81346',
#  'dataset_status': 'New',
#  'dataset_uuid': '7034950e109586361e73c1b9ddb81346',
#  'donor_group_name': ['Stanford TMC'],
#  'donor_hubmap_id': ['HBM275.QBCZ.562'],
#  'donor_submission_id': ['STAN0014'],
#  'donor_uuid': ['142d18f0a749d3d02d8b1addbca15589'],
#  'first_sample_hubmap_id': ['HBM438.JGJH.887'],
#  'first_sample_portal_url': ['https://portal.hubmapconsortium.org/browse/sample/5058beb6cdf7e9445d3e3d944822762e'],
#  'first_sample_submission_id': ['STAN0014-SI-2-1'],
#  'first_sample_type': ['block'],
#  'first_sample_uuid': ['5058beb6cdf7e9445d3e3d944822762e'],
#  'lab_id_or_name': 'B011-A-405-Small-Intestine-Proximal-Jejunum-CODEX',
#  'organ_hubmap_id': ['HBM342.SZCR.585'],
#  'organ_submission_id': ['STAN0014-SI'],
#  'organ_type': ['small intestine'],
#  'organ_uuid': ['411319bc691ba1e91dadac6262193507'],
#  'processed_dataset_hubmap_id': [],
#  'processed_dataset_portal_url': [],
#  'processed_dataset_status': [],
#  'processed_dataset_uuid': [],
#  'rui_location_hubmap_id': ['HBM438.JGJH.887'],
#  'rui_location_submission_id': ['STAN0014-SI-2-1'],
#  'rui_location_uuid': ['5058beb6cdf7e9445d3e3d944822762e'],
#  'sample_metadata_hubmap_id': [],
#  'sample_metadata_submission_id': [],
#  'sample_metadata_uuid': []}

# %% [markdown]
# #### Unpublished

# %%
nexus_token = "Agd373rPmMWnXaWYV7K61jvMOEvjkYBVaK9oEwPvywyxkrlvy0UXCopKXywKJopxG3vV8MgG3wv4ODuMX0oBrCrPa8"
headers = {
    # 'accept': 'application/json',
    # 'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + nexus_token
}

BASE_URL = "https://entity.api.hubmapconsortium.org/"
endpoint = f"datasets/unpublished"
params = {
    "format" : "json",
}
URL = BASE_URL + endpoint
resp = requests.get(URL, headers=headers, params=params)

# %%
[resp.json()]
# Out:
# 1942

# %%
unpublished_dataset_uuids = [dt['uuid'] for dt in resp.json()]

# %%
unpublished_dataset_uuids[:5]
# Out:
# ['9b82e4f2bd429e49ec632c3132d380a5',
#  '34056fbd3adb97f19a653390869ea1de',
#  'a7446cfb37adfac308eb69ec307dd69a',
#  '4176c40f5512a6e8fbc9c6975ddec2b5',
#  '2fdbf2be6b297eb1951b11db5b79cadb']

# %% [markdown]
# #### Entity fetch

# %%
nexus_token = "Agd373rPmMWnXaWYV7K61jvMOEvjkYBVaK9oEwPvywyxkrlvy0UXCopKXywKJopxG3vV8MgG3wv4ODuMX0oBrCrPa8"
headers = {
    # 'accept': 'application/json',
    # 'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + nexus_token
}
ID = unpublished_dataset_uuids[1]

BASE_URL = "https://entity.api.hubmapconsortium.org/"
endpoint = f"entities/{ID}"
params = {
    "id" : ID,
}
URL = BASE_URL + endpoint
resp = requests.get(URL, headers=headers, )

# %%
resp.json()
# Out:
# {'contains_human_genetic_sequences': False,
#  'created_by_user_displayname': 'HuBMAP Process',
#  'created_by_user_email': 'hubmap@hubmapconsortium.org',
#  'created_by_user_sub': '3e7bce63-129d-33d0-8f6c-834b34cd382e',
#  'created_timestamp': 1665511059282,
#  'data_access_level': 'consortium',
#  'data_types': ['AF'],
#  'description': 'Autofluorescence Microscopy collected from the left kidney of a 66 year old White male donor\nby the Biomolecular Multimodal Imaging Center (BIOMC) at Vanderbilt University. BIOMIC is a Tissue Mapping Center\nthat is part of the NIH funded Human Biomolecular Atlas Program (HuBMAP). Autofluorescence images were\ncollected with a Carl Zeiss microscopy AxioScan.Z1 using 3 channels/filters --\nDAPI (excitation: 335-383 nm/emission: 420-470 nm), eGFP (excitation: 450-490 nm/emission: 500-550 nm),\nand dsRed (excitation: 538-562 nm/emission: 570-640 nm). Support was provided by the NIH Common Fund\nand National Institute of Diabetes and Digestive and Kidney Diseases (U54 DK120058). Tissue was collected through\nthe Cooperative Human Tissue Network with support provided by the NIH National Cancer Institute (5 UM1 CA183727-08).',
#  'direct_ancestors': [{'created_by_user_displayname': 'Jamie Allen',
#    'created_by_user_email': 'jamie.l.allen@vanderbilt.edu',
#    'created_by_user_sub': '83ae233d-6d1d-40eb-baa7-b6f636ab579a',
#    'created_timestamp': 1629997242281,
#    'data_access_level': 'consortium',
#    'description': '08/02/21:  DR3  1-4-proteomics, 5-8-lipidomics, 9-PAS, 10-Codex, 11-IMS, 12-Codex, 13-IMS, 14-DSP, 15-IMS, 16-LCM, 17-uLESA, 18-Prot, 19-Met, 20-MXIF, 21-PAS',
#    'entity_type': 'Sample',
#    'group_name': 'Vanderbilt TMC',
#    'group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#    'hubmap_id': 'HBM493.PMZQ.923',
#    'last_modified_timestamp': 1629997242281,
#    'last_modified_user_displayname': 'Jamie Allen',
#    'last_modified_user_email': 'jamie.l.allen@vanderbilt.edu',
#    'last_modified_user_sub': '83ae233d-6d1d-40eb-baa7-b6f636ab579a',
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bfskjncw',
#    'sample_category': 'section',
#    'specimen_type': 'fresh_frozen_tissue_section',
#    'submission_id': 'VAN0007-LK-202-9',
#    'tissue_type': 'Section',
#    'uuid': '93b51537a638fb29c7df9584beeecd4b'}],
#  'entity_type': 'Dataset',
#  'group_name': 'Vanderbilt TMC',
#  'group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#  'hubmap_id': 'HBM858.MFFT.638',
#  'last_modified_timestamp': 1665511059282,
#  'last_modified_user_displayname': 'HuBMAP Process',
#  'last_modified_user_email': 'hubmap@hubmapconsortium.org',
#  'last_modified_user_sub': '3e7bce63-129d-33d0-8f6c-834b34cd382e',
#  'local_directory_rel_path': 'consortium/Vanderbilt TMC/34056fbd3adb97f19a653390869ea1de/',
#  'provider_info': 'BIOMIC DR3 autofluorescence microscopy paired with non-IMS PAS stained section : VAN0007-LK-202-9-AF',
#  'status': 'New',
#  'title': 'autofluorescence microscopy data from the kidney (left) of a 66-year-old white female',
#  'uuid': '34056fbd3adb97f19a653390869ea1de'}

# %% [markdown]
# #### Get all unpublished data

# %%
def get_unpublished_dataset_metadata(nexus_token, uuid):
    # nexus_token = "Agd373rPmMWnXaWYV7K61jvMOEvjkYBVaK9oEwPvywyxkrlvy0UXCopKXywKJopxG3vV8MgG3wv4ODuMX0oBrCrPa8"
    headers = {
        'Authorization': 'Bearer ' + nexus_token
    }

    BASE_URL = "https://entity.api.hubmapconsortium.org/"
    endpoint = f"entities/{uuid}"
    URL = BASE_URL + endpoint
    resp = requests.get(URL, headers=headers)
    return resp


def get_all_hubmap_unpublished_dataset_uuids(nexus_token):
    headers = {
        'Authorization': 'Bearer ' + nexus_token
    }

    BASE_URL = "https://entity.api.hubmapconsortium.org/"
    endpoint = f"datasets/unpublished"
    params = {
        "format" : "json",
    }
    URL = BASE_URL + endpoint
    resp = requests.get(URL, headers=headers, params=params)
    unpublished_dataset_uuids = []
    if resp.status_code == 200:
        unpublished_dataset_uuids = [dt['uuid'] for dt in resp.json()]
    else:
        return {"error": "Unable to fetch unpublished dataset prov-info."}
    return unpublished_dataset_uuids


def get_all_hubmap_unpublished_dataset_metadata(nexus_token):
    unpublished_dataset_uuids = get_all_hubmap_unpublished_dataset_uuids(nexus_token)
    print(f"Total unpublished datasets : {len(unpublished_dataset_uuids)}")

    all_unpublished_dataset_metadata = {}
    failed_unpublished_fetches = []

    for uuid in tqdm(unpublished_dataset_uuids, desc="Fetching unpublished HuBMAP dataset metadata: "):    
        resp = get_unpublished_dataset_metadata(nexus_token, uuid)
        if resp.status_code != 200:
            failed_unpublished_fetches.append(uuid)
        else:
            all_unpublished_dataset_metadata[uuid] = resp.json()

        
    return all_unpublished_dataset_metadata, failed_unpublished_fetches

# %%
nexus_token = "Agd373rPmMWnXaWYV7K61jvMOEvjkYBVaK9oEwPvywyxkrlvy0UXCopKXywKJopxG3vV8MgG3wv4ODuMX0oBrCrPa8"
all_unpublished_dataset_metadata, failed_unpublished_fetches = get_all_hubmap_unpublished_dataset_metadata(nexus_token)
# Out:
# Fetching unpublished HuBMAP dataset metadata:   0%|          | 0/1942 [00:00<?, ?it/s]
# Total unpublished datasets : 1942
# Fetching unpublished HuBMAP dataset metadata: 100%|██████████| 1942/1942 [25:01<00:00,  1.29it/s]

# %%
all_unpublished_dataset_metadata

# %%
len(all_unpublished_dataset_metadata)
# Out:
# 1938

# %%
all_unpublished_dataset_metadata['9b82e4f2bd429e49ec632c3132d380a5']
# Out:
# {'contains_human_genetic_sequences': False,
#  'created_by_user_displayname': 'HuBMAP Process',
#  'created_by_user_email': 'hubmap@hubmapconsortium.org',
#  'created_by_user_sub': '3e7bce63-129d-33d0-8f6c-834b34cd382e',
#  'created_timestamp': 1665511029046,
#  'data_access_level': 'consortium',
#  'data_types': ['AF'],
#  'description': 'Autofluorescence Microscopy collected from the left kidney of a 66 year old White male donor\nby the Biomolecular Multimodal Imaging Center (BIOMC) at Vanderbilt University. BIOMIC is a Tissue Mapping Center\nthat is part of the NIH funded Human Biomolecular Atlas Program (HuBMAP). Autofluorescence images were\ncollected with a Carl Zeiss microscopy AxioScan.Z1 using 3 channels/filters --\nDAPI (excitation: 335-383 nm/emission: 420-470 nm), eGFP (excitation: 450-490 nm/emission: 500-550 nm),\nand dsRed (excitation: 538-562 nm/emission: 570-640 nm). Support was provided by the NIH Common Fund\nand National Institute of Diabetes and Digestive and Kidney Diseases (U54 DK120058). Tissue was collected through\nthe Cooperative Human Tissue Network with support provided by the NIH National Cancer Institute (5 UM1 CA183727-08).',
#  'direct_ancestors': [{'created_by_user_displayname': 'Jamie Allen',
#    'created_by_user_email': 'jamie.l.allen@vanderbilt.edu',
#    'created_by_user_sub': '83ae233d-6d1d-40eb-baa7-b6f636ab579a',
#    'created_timestamp': 1629997242281,
#    'data_access_level': 'consortium',
#    'description': '08/02/21:  DR3  1-4-proteomics, 5-8-lipidomics, 9-PAS, 10-Codex, 11-IMS, 12-Codex, 13-IMS, 14-DSP, 15-IMS, 16-LCM, 17-uLESA, 18-Prot, 19-Met, 20-MXIF, 21-PAS',
#    'entity_type': 'Sample',
#    'group_name': 'Vanderbilt TMC',
#    'group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#    'hubmap_id': 'HBM493.PMZQ.923',
#    'last_modified_timestamp': 1629997242281,
#    'last_modified_user_displayname': 'Jamie Allen',
#    'last_modified_user_email': 'jamie.l.allen@vanderbilt.edu',
#    'last_modified_user_sub': '83ae233d-6d1d-40eb-baa7-b6f636ab579a',
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bfskjncw',
#    'sample_category': 'section',
#    'specimen_type': 'fresh_frozen_tissue_section',
#    'submission_id': 'VAN0007-LK-202-9',
#    'tissue_type': 'Section',
#    'uuid': '93b51537a638fb29c7df9584beeecd4b'}],
#  'entity_type': 'Dataset',
#  'group_name': 'Vanderbilt TMC',
#  'group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#  'hubmap_id': 'HBM958.PNXC.824',
#  'last_modified_timestamp': 1665511029046,
#  'last_modified_user_displayname': 'HuBMAP Process',
#  'last_modified_user_email': 'hubmap@hubmapconsortium.org',
#  'last_modified_user_sub': '3e7bce63-129d-33d0-8f6c-834b34cd382e',
#  'local_directory_rel_path': 'consortium/Vanderbilt TMC/9b82e4f2bd429e49ec632c3132d380a5/',
#  'provider_info': 'BIOMIC DR3 autofluorescence microscopy paired with non-IMS PAS stained section : VAN0007-LK-202-9-AF',
#  'status': 'New',
#  'title': 'autofluorescence microscopy data from the kidney (left) of a 66-year-old white female',
#  'uuid': '9b82e4f2bd429e49ec632c3132d380a5'}

# %% [markdown]
# # Parallel fetching

# %%
import asyncio
from aiohttp import ClientSession

import nest_asyncio
nest_asyncio.apply()

# %%
async def fetch(url, session):
    async with session.get(url) as response:
        return await response.json()


async def bound_fetch(sem, url, session):
    # Getter function with semaphore.
    async with sem:
        return await fetch(url, session)
    
    
def get_all_hubmap_unpublished_dataset_uuids(nexus_token):
    headers = {
        'Authorization': 'Bearer ' + nexus_token
    }

    BASE_URL = "https://entity.api.hubmapconsortium.org/"
    endpoint = f"datasets/unpublished"
    params = {
        "format" : "json",
    }
    URL = BASE_URL + endpoint
    resp = requests.get(URL, headers=headers, params=params)
    unpublished_dataset_uuids = []
    if resp.status_code == 200:
        unpublished_dataset_uuids = [dt['uuid'] for dt in resp.json()]
    else:
        return {"error": "Unable to fetch unpublished dataset prov-info."}
    return unpublished_dataset_uuids


async def get_multiple_unpublished_dataset_metadata(unpublished_dataset_uuids, max_requests_per_sec):
    tasks = []
    headers = {
        'Authorization': 'Bearer ' + nexus_token
    }
    sem = asyncio.Semaphore(max_requests_per_sec)

    async with ClientSession(headers=headers) as session:
        for uuid in unpublished_dataset_uuids:    
            url = f"https://entity.api.hubmapconsortium.org/entities/{uuid}"
            task = asyncio.ensure_future(bound_fetch(sem, url, session))
            tasks.append(task)
            
        
        responses = asyncio.gather(*tasks)
        return await responses


def get_all_hubmap_unpublished_dataset_metadata_parallel(nexus_token, max_requests_per_sec=50):
    unpublished_dataset_uuids = get_all_hubmap_unpublished_dataset_uuids(nexus_token)
    print(f"Total unpublished datasets : {len(unpublished_dataset_uuids)}")

    all_unpublished_dataset_metadata = []
    failed_unpublished_fetches = []
    
    for i in tqdm(range(0, len(unpublished_dataset_uuids), max_requests_per_sec), desc="Fetching unpublished data parallel"):
        loop = asyncio.get_event_loop()
        future = asyncio.ensure_future(get_multiple_unpublished_dataset_metadata(unpublished_dataset_uuids[i:i+max_requests_per_sec], max_requests_per_sec))
        all_unpublished_dataset_metadata += loop.run_until_complete(future)

        
    return all_unpublished_dataset_metadata

# %%
# %%time 

nexus_token = "Ag7paXD5MqbJ0na8VMvNa09an5N3e8GQGK0xVNr32ppk34bXawHWC27Gxkk2W7JP9qq6BVBxb9bw86Cno2apBtBxvr"
all_unpublished_dataset_metadata = get_all_hubmap_unpublished_dataset_metadata_parallel(nexus_token, max_requests_per_sec=200)
# Out:
# Fetching unpublished data parallel:   0%|          | 0/10 [00:00<?, ?it/s]
# Total unpublished datasets : 1949
# Fetching unpublished data parallel: 100%|██████████| 10/10 [02:05<00:00, 12.51s/it]
# CPU times: user 4.78 s, sys: 1.5 s, total: 6.27 s
# Wall time: 2min 10s

# %%
len(all_unpublished_dataset_metadata)
# Out:
# 1948

# %%
all_unpublished_dataset_metadata_dict = {dt['uuid'] : dt for dt in all_unpublished_dataset_metadata}

# %%
all_unpublished_dataset_metadata_dict['9b82e4f2bd429e49ec632c3132d380a5']
# Out:
# {'contains_human_genetic_sequences': False,
#  'created_by_user_displayname': 'HuBMAP Process',
#  'created_by_user_email': 'hubmap@hubmapconsortium.org',
#  'created_by_user_sub': '3e7bce63-129d-33d0-8f6c-834b34cd382e',
#  'created_timestamp': 1665511029046,
#  'data_access_level': 'consortium',
#  'data_types': ['AF'],
#  'description': 'Autofluorescence Microscopy collected from the left kidney of a 66 year old White male donor\nby the Biomolecular Multimodal Imaging Center (BIOMC) at Vanderbilt University. BIOMIC is a Tissue Mapping Center\nthat is part of the NIH funded Human Biomolecular Atlas Program (HuBMAP). Autofluorescence images were\ncollected with a Carl Zeiss microscopy AxioScan.Z1 using 3 channels/filters --\nDAPI (excitation: 335-383 nm/emission: 420-470 nm), eGFP (excitation: 450-490 nm/emission: 500-550 nm),\nand dsRed (excitation: 538-562 nm/emission: 570-640 nm). Support was provided by the NIH Common Fund\nand National Institute of Diabetes and Digestive and Kidney Diseases (U54 DK120058). Tissue was collected through\nthe Cooperative Human Tissue Network with support provided by the NIH National Cancer Institute (5 UM1 CA183727-08).',
#  'direct_ancestors': [{'created_by_user_displayname': 'Jamie Allen',
#    'created_by_user_email': 'jamie.l.allen@vanderbilt.edu',
#    'created_by_user_sub': '83ae233d-6d1d-40eb-baa7-b6f636ab579a',
#    'created_timestamp': 1629997242281,
#    'data_access_level': 'consortium',
#    'description': '08/02/21:  DR3  1-4-proteomics, 5-8-lipidomics, 9-PAS, 10-Codex, 11-IMS, 12-Codex, 13-IMS, 14-DSP, 15-IMS, 16-LCM, 17-uLESA, 18-Prot, 19-Met, 20-MXIF, 21-PAS',
#    'entity_type': 'Sample',
#    'group_name': 'Vanderbilt TMC',
#    'group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#    'hubmap_id': 'HBM493.PMZQ.923',
#    'last_modified_timestamp': 1629997242281,
#    'last_modified_user_displayname': 'Jamie Allen',
#    'last_modified_user_email': 'jamie.l.allen@vanderbilt.edu',
#    'last_modified_user_sub': '83ae233d-6d1d-40eb-baa7-b6f636ab579a',
#    'protocol_url': 'dx.doi.org/10.17504/protocols.io.bfskjncw',
#    'sample_category': 'section',
#    'specimen_type': 'fresh_frozen_tissue_section',
#    'submission_id': 'VAN0007-LK-202-9',
#    'tissue_type': 'Section',
#    'uuid': '93b51537a638fb29c7df9584beeecd4b'}],
#  'entity_type': 'Dataset',
#  'group_name': 'Vanderbilt TMC',
#  'group_uuid': '73bb26e4-ed43-11e8-8f19-0a7c1eab007a',
#  'hubmap_id': 'HBM958.PNXC.824',
#  'last_modified_timestamp': 1665511029046,
#  'last_modified_user_displayname': 'HuBMAP Process',
#  'last_modified_user_email': 'hubmap@hubmapconsortium.org',
#  'last_modified_user_sub': '3e7bce63-129d-33d0-8f6c-834b34cd382e',
#  'local_directory_rel_path': 'consortium/Vanderbilt TMC/9b82e4f2bd429e49ec632c3132d380a5/',
#  'provider_info': 'BIOMIC DR3 autofluorescence microscopy paired with non-IMS PAS stained section : VAN0007-LK-202-9-AF',
#  'status': 'New',
#  'title': 'autofluorescence microscopy data from the kidney (left) of a 66-year-old white female',
#  'uuid': '9b82e4f2bd429e49ec632c3132d380a5'}

# %%
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%Y_%M_%d_%H_%M_%S")
print("Current Time =", current_time)
# Out:
# Current Time = 2023_10_01_12_10_19
